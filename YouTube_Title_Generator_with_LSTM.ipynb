# %%
#Basic Libraries to get started with the eco-system
import pandas as pd
import string
import numpy as np
import json

# %%
from keras.preprocessing.sequence import pad_sequences #To pad sequences to same length
from keras.layers import Embedding, LSTM, Dense, Dropout
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping # Stop training when a monitored metric has stopped improving.

import tensorflow as tf
import keras.utils as ku
from keras.models import Sequential
from numpy.random import seed

tf.random.set_seed(2)
seed(1)

# %%
# !git clone https://github.com/ehsanayaz/Title-Generator-with-LSTM
# Out:
# Cloning into 'Title-Generator-with-LSTM'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 9 (delta 3), reused 9 (delta 3), pack-reused 0
# Unpacking objects: 100% (9/9), done.

# %%
df1 = pd.read_csv('/content/Title-Generator-with-LSTM/Data/USvideos.csv')
df2 = pd.read_csv('/content/Title-Generator-with-LSTM/Data/CAvideos.csv')
df3 = pd.read_csv('/content/Title-Generator-with-LSTM/Data/GBvideos.csv')

# %%
#load the datasets containing the category names
data1 = json.load(open('/content/Title-Generator-with-LSTM/Data/US_category_id.json'))
data2 = json.load(open('/content/Title-Generator-with-LSTM/Data/CA_category_id.json'))
data3 = json.load(open('/content/Title-Generator-with-LSTM/Data/GB_category_id.json'))

# %%
#Helper function to extract categories 
def category_extractor(data):
    i_d = [data['items'][i]['id'] for i in range(len(data['items']))]
    title = [data['items'][i]['snippet']["title"] for i in range(len(data['items']))]
    i_d = list(map(int, i_d))
    category = zip(i_d, title)
    category = dict(category)
    return category

# %%
#Calling the helper function
df1['category_title'] = df1['category_id'].map(category_extractor(data1))
df2['category_title'] = df2['category_id'].map(category_extractor(data2))
df3['category_title'] = df3['category_id'].map(category_extractor(data3))

# %%
#Dataframe Preparation 
df = pd.concat([df1, df2, df3], ignore_index=True) #Concatenating all 3 dfs
df = df.drop_duplicates('video_id') #'Video_id' has no contextual value for our case

df
# Out:
#            video_id  ...   category_title
# 0       2kyS6SvSYSE  ...   People & Blogs
# 1       1ZAPwfrtAFY  ...    Entertainment
# 2       5qpjK5DgCt4  ...           Comedy
# 3       puqaWrEC7tY  ...    Entertainment
# 4       d380meD0W0M  ...    Entertainment
# ...             ...  ...              ...
# 120428  9iM7W1Dvl6Q  ...    Entertainment
# 120589  g4txv3A9ICQ  ...            Music
# 120593  YQJmvXamKYg  ...  News & Politics
# 120623  BOhylL90UVQ  ...            Music
# 120717  14G7Qw5DC9M  ...    Howto & Style
#
# [30318 rows x 17 columns]

# %%
entertainment = df[df['category_title']=='Entertainment']['title']  #Selecting tittle of videos in 'Entertainment' category only
entertainment #Before
# Out:
# 1         The Trump Presidency: Last Week Tonight with J...
# 3                          Nickelback Lyrics: Real or Fake?
# 4                                  I Dare You: GOING BALD!?
# 6                 Roy Moore & Jeff Sessions Cold Open - SNL
# 11        (SPOILERS) 'Shiva Saves the Day' Talked About ...
#                                 ...
# 119803    [SHINee - Good Evening] Comeback Stage | M COU...
# 119910    JUSTICE LEAGUE Is Better Than Infinity Wars | ...
# 119947    Diddy & King Combs on The Four, Rap Beef, NFL ...
# 120425    Hilary Duff Is Having a Baby Girl and Her Son ...
# 120428         GLOW: Season 2 | Main Trailer [HD] | Netflix
# Name: title, Length: 9730, dtype: object

# %%
entertainment = entertainment.tolist() 
entertainment #After
# Out:
# ['The Trump Presidency: Last Week Tonight with John Oliver (HBO)',
#  'Nickelback Lyrics: Real or Fake?',
#  'I Dare You: GOING BALD!?',
#  'Roy Moore & Jeff Sessions Cold Open - SNL',
#  "(SPOILERS) 'Shiva Saves the Day' Talked About Scene Ep. 804 | The Walking Dead",
#  'SPAGHETTI BURRITO VS SPAGHETTI BURRITO',
#  'Amazon Christmas Advert 2017 - Toys & Games',
#  "What's Inside a Detectives Car?",
#  'People are Awesome & The Pet Collective present Pets are Awesome!',
#  'ELDERS REACT TO iPHONE X (Facial Recognition, Animojis)',
#  'Will It Watermarble?! Sister Edition | Watermarbling 9 random objects in nail polish!',
#  'Jason Momoa Wows Hugh Grant With Some Dothraki | The Graham Norton Show',
#  "Daddy's Home 2 - Movie Review",
#  '#VeteransDay: Thank You for Everything',
#  'Batman: Gotham by Gaslight - Exclusive Trailer (2018)',
#  'Watch Norman Reedus Come Face to Face with his ‘Walking Dead’ Double',
#  'Reacting to Running a Half Marathon | MEGANBYTES EP. 101',
#  'Justice League Reactions, Should Disney Buy Netflix - The John Campea Show',
#  'Rosie O’Donnell On Donald Trump’s Hostility Toward Her | WWHL',
#  'Jason Momoa & Lisa Bonet: Love at First Sight',
#  'FANTASY (feat. Amber Liu) by SUPERFRUIT',
#  'Taylor Swift - “New Year’s Day” Fan Performance',
#  'H&M Holiday 2017 starring Nicki Minaj – official teaser',
#  'Owen Wilson on Meeting Julia Roberts, and Tandem Biking',
#  'Meryl Streep Meets Anna Wintour at Vogue',
#  'I Trained To Become Batman 🦇 (Justice League)',
#  "Sean Astin Knew Nothing About 'Lord Of The Rings' Once Upon A Time",
#  'President Bill Clinton On Dictators, Democracy, & Why We Need Immigrants More Than Ever',
#  'A Day in The Life of David Letterman',
#  'Live in the now!',
#  'Dark | Official Trailer [HD] | Netflix',
#  "Where is TOKYO'S GREATEST View?",
#  'Dropping And CATCHING A Paper Airplane At 2,000 Feet!',
#  'I Miss the Old Taylor',
#  'Keith Urban - Female (Official Audio)',
#  'Harry Styles canta Sign Of The Times a X Factor Italia - Live Show 3',
#  "KUWTK | Scott Gets Upset Over Being Uninvited to Khloe K.'s Party | E!",
#  "O.T. Genasis Talks About His Come Up, Opens Up About His Son's Autism  + More",
#  'Tamar Braxton Talks Divorce In First Interview',
#  'Fire breathing full twist backflips in one minute - Guinness World Records Day',
#  'BEAUTY GURU GETS A MAKEOVER... FINALE',
#  'Brian Justin Crum - Wild Side',
#  'Katy Perry - Swish Swish (Behind the Scenes with Just Dance)',
#  "Selena Gomez Singing Wolves and It Ain't Me FULL Instagram Live | Acoustic",
#  'How To Do Thanksgiving Makeup That Has Nothing To Do With The 566 Federally Recognized Tribes',
#  'Slow Mo Katana Sword - 4K - The Slow Mo Guys',
#  'Jason Momoa Shows Off His Aquaman Quindent | The Graham Norton Show',
#  'American Crime Story Season 2: The Assassination of Gianni Versace Trailer (HD)',
#  '10 LIFE HACKS YOU NEED TO KNOW with TEENS (REACT)',
#  'DISNEY SENT MICKEY MOUSE TO MY HOUSE!',
#  "Does Gwen Stefani Know If Blake Shelton Is People's Sexiest Man Alive? | Access Hollywood",
#  'funfetti is extremely fun',
#  'Lindsey and\u200b Mark’s - Iconic Dance - Dancing with the Stars',
#  'Colin Farrell Dishes on Rendezvous with Girlfriend',
#  'Taylor Swift Instagram Story - Target 11/14/17',
#  '100 People Hold Their Breath for as Long as They Can',
#  'Victoria Beckham Gives Strangers Fashion Advice for $2 in Central Park | Vanity Fair',
#  'Model Fei Fei Sun Perform Skin-Care Magic | Beauty Secrets | Vogue',
#  'Justice League | “Come Together” | Todrick Hall, J.Fla, Mario Bautista, Samantha Harvey, Clara Marz',
#  'Jaden Smith: Watch Me',
#  "All of Jim's Best Pranks  - The Office US",
#  "'Lord of the Rings' TV Series Gets Multi-Season Order At Amazon | News Flash | Entertainment Weekly",
#  '5 Strange Things That Happened to Stranger Things’ Joe Keery on His GQ Photo Shoot',
#  'P!nk Carpool Karaoke',
#  'Justice League - Movie Review',
#  'Kim Kardashian Lets Gender of Third Child Slip',
#  'Larry David Outtakes – Mean Tweets About Jimmy Kimmel',
#  'Demi Lovato & Luis Fonsi - Echame La Culpa (Teaser)',
#  'How to be an Aquarius',
#  'KUWTK | Kris Jenner Brings Her Personal Scribe to Lunch | E!',
#  "Kim Kardashian Explains Her Family's Rumor Control Rule",
#  "Justice League - Movie Review Is It What We've Been Waiting For?",
#  'MENACE: the pile of matchboxes which can learn',
#  'Remy Ma is on Top of the World',
#  "Inside Danica Roem's Historic Victory",
#  'Jordan\u200b and\u200b \u200bLindsay’s - Iconic Dance - Dancing with the Stars',
#  'Lord of the Rings TV Series Lands At Amazon & Will Explore New Stories',
#  'RAMPAGE - OFFICIAL TRAILER 1 [HD]',
#  'Spill Your Guts or Fill Your Guts w/ Kim Kardashian',
#  "Miranda Sings Hijacks a Stranger's Tinder | Vanity Fair",
#  '73 Questions With Liza Koshy | Vogue',
#  "Jordan Peele Crashed A 'Get Out' College Course",
#  "The Talk - Eve Reacts to Nicki Minaj's Racy Magazine Cover, 'I just don't think it's right'",
#  'Blake Shelton Is Milking His Title of Sexiest Man Alive',
#  "HOLO CAPPUCCINO | DIY Diamond Cappuccino test (maybe don't drink this?)",
#  'Justice League - Movie Review',
#  'Should Hillary Clinton Be Impeached?',
#  'Who Matt Reeves Wants As Batman, Is Basmati Blues Culturally Insensitive? The John Campe Show',
#  'Deadpool 2 Teaser Released - Movie Talk',
#  'Runners by DANakaDAN (Official Music Video) | Wong Fu Presents',
#  'Behind The Curtain - OFFICIAL TRAILER',
#  'F The Prom (2017) | Official Trailer HD',
#  'The Bipartisan Pastime Of Harassing Women',
#  'Lin-Manuel Miranda and Macey Hensley Face Off in Historical Trivia',
#  "Kim Kardashian's Surrogate Didn't Know Whose Baby She Was Carrying!",
#  'Macklemore’s Naked Justin Bieber Painting | WWHL',
#  'Tracee Ellis Ross on Cher, Michael Jackson & Diana Ross',
#  'TODRICK RETURNS TO BROADWAY',
#  'A Christmas Prince | Official Trailer [HD] | Netflix',
#  'KEEP ME COMING by SUPERFRUIT',
#  'KUWTK | A Very Kardashian Holiday Sneak Peek | E!',
#  'MOTOR SPORT - Cardi B x Migos x Nicki Minaj Dance | Matt Steffanina cover',
#  '#StarOnFox Exclusive Clip for TheYBF.com',
#  'Religion Of Sports Season 2 - Trailer 1',
#  'Chance-giving Monologue - SNL',
#  'Dont Hurt Me.',
#  'TRANSFORMING SUMMER MCKEEN INTO ME!!',
#  'Will Ferrell Left Speechless as Mark Wahlberg Reveals He Has a Third Nipple! | Good Morning Britain',
#  'Diana Ross Lost Her Fanny Pack',
#  '[HD] Julia Roberts Interview On Today Show 11/16/2017',
#  'BALL SURPRISE PRANK (woody and kleiny)',
#  'R.I.P Arya',
#  'Weekend Update on Senator Al Franken - SNL',
#  'Gordon is Served “The Weirdest Pizza I’ve Ever Seen!” | Kitchen Nightmares',
#  'Funny Japanese Game Show Slippery Stairs - Just Hilarious',
#  'Jon Stewart Hosts Night of Too Many Stars',
#  'Drug Store Nail Powders FAIL (what the Sally Hansen?!)',
#  'JUSTICE LEAGUE Spoiler Review and Discussion',
#  'Mali Music and Jennifer Hudson are recording a song!',
#  'Cooking A Turkey on a Car Engine',
#  "Making The Grand Tour: Mark Webber's Driver Audition",
#  'Highlights from the 2017 American Music Awards',
#  'Come Back, Barack - SNL',
#  'Holding a Baby for the First Time in Slow Motion - First Takes',
#  "Marvel's Agents of SHIELD Season 5 Trailer (HD)",
#  '2017 American Music Awards: All The Show-Stopping Performances!',
#  'JUSTICE LEAGUE A Box Office Disaster - Box Office Report',
#  "McDonald's Will No Longer Serve This Fan Favorite Drink",
#  'DIY CLEAR PUMPKIN PIE',
#  'grown-ish | grown-ish x b-fast club | Freeform',
#  "Stranger Things Cast Answer the Web's Most Searched Questions | WIRED",
#  "Binging with Babish: Rachel's Trifle from Friends",
#  'Sofia Vergara Wants to See Ellen in Her Underwear',
#  'The Voice 2017 - Pitch Perfect 3 x The Voice Freedom! ’90 x Cups” (Digital Exclusive)',
#  'Liza Koshy Touches a Bearded Dragon, Chinchilla & Other Weird Stuff in the Fear Box | Vanity Fair',
#  'THANKSGIVING SLAY MAKEUP TUTORIAL',
#  'Victoria’s Secret Model Sara Sampaio’s Easy Bombshell Makeup Look | Beauty Secrets | Vogue',
#  'Lindsey and\u200b Mark’s - Freestyle - Dancing with the Stars',
#  'Volunteering with YouTubers',
#  'How to do a beauty Vlog for Tarte Cosmetics',
#  "Kate Bosworth & Shemar Moore Disagree on People's Sexiest Man",
#  'African Grey Parrot swearing in an Irish accent',
#  'Terry Crews Says He Was Sexually Assaulted',
#  'The Poop In My Pants | Rick and Morty | Adult Swim',
#  'The Internet Is UNDER ATTACK, Net Neutrality is Dying, and What You Can Do...',
#  'The happiest day of my life',
#  'Jet Packinski Touches a Hairless Rat, Rooster & Other Weird Stuff in the Fear Box | Vanity Fair',
#  'CHICKEN GIRLS | Annie & Hayden in “Broken” | Ep. 8',
#  'How To Design A Comic Book Page',
#  'Ellen Surprises the Audience with Channing Tatum During 12 Days!',
#  'What Went Wrong With Justice League At The Box Office',
#  'Camila Mendes Has Twitter Problems',
#  "Daveed Diggs Doesn't Always Cry At Movies, Just His Own",
#  'Sneaking in EVERYWHERE for FREE (Yellow Vest Experiment)',
#  'The Crown - Season 2 | Trailer: Philip [HD] | Netflix',
#  'Jordan\u200b and\u200b \u200bLindsay’s - Repeat - Dancing with the Stars',
#  '12 STRONG - Official Trailer 2',
#  "Zendaya's Wavy-Curly Hair Tutorial",
#  'Justice League Could Lose WB Big Money - SJU',
#  "Saoirse Ronan on Harassment, Need to Know There's Support Here No Matter What | Close Up With THR",
#  'Are Critics What Killed Justice League? Sony Pay Too Much For Tarantino? - The John Campea Show',
#  "Christina Aguilera's Whitney Houston Tribute At AMAs Is Breathtaking | AMAs 2017 | Access Hollywood",
#  'Ford Thunderbird SC commercial (1989)',
#  '2017 American Music Awards: Red Carpet Fashion | E! News',
#  'KUWTK | Kris Jenner & Jonathan Cheban Put on Disguises | E!',
#  'Jackson Pollock in 60 seconds',
#  'Masters Of The Sun: The Zombie Chronicles Augmented Reality Experience Release Date Trailer',
#  'Verizon 360 Live: The Macy’s Thanksgiving Day Parade',
#  'Krysten Ritter Has Weak Tinder Game',
#  'SMALLFOOT - Teaser Trailer',
#  'Black Mirror - Arkangel | Official Trailer [HD] | Netflix',
#  'FAIL COMPILATION - MASSIVE Chain Reaction goes UP the Stairs! ft. berlagawesome',
#  'Glowing Speaker iPhone Mod! See Your Music in RGB!',
#  'Pitch Perfect 3 x The Voice Freedom! ’90 x Cups',
#  'Sarah Michelle Gellar Vs. Sarah Michelle Prinze',
#  'Pitch Perfect 3 - Riff-Off Clip [HD]',
#  'Marvel’s Agents of S.H.I.E.L.D. | Season 5 Premiere Special Preview',
#  '2017 Miss Universe National Costume Show',
#  "My Dad Paints My Nails (he doesn't know what YouTube is)",
#  "Making The Grand Tour: James's Candidate for the Driver",
#  'Sesame Street: Sharing Things (Stranger Things Parody)',
#  'Meghan Markle Engaged To Prince Harry | The View',
#  'Ray J. and Princess Love’s Big News!',
#  'Black Mirror - Crocodile | Official Trailer [HD] | Netflix',
#  "Ellen Makes 'Friends' with BTS!",
#  'Ed Sheeran delivers a Perfect performance | Live Shows | The X Factor 2017',
#  "Miss Universe Crowd Shouts 'Boo!' Not Happy with Ms. Jamaica Just 2nd Runner Up?",
#  "RHOA: Kim Zolciak-Biermann Says Kenya Moore's Husband Doesn't Exist (Season 10, Episode 4) | Bravo",
#  'TEENS READ 10 FUNNY FRIEND ZONE TEXTS (REACT)',
#  'The Voice 2017 - Team Miley: Man! I Feel Like a Woman',
#  'How-To Make a Steak Sandwich with Matty Matheson',
#  "Jennifer Lawrence: 'I Become Incredibly Rude' to Avoid Fan Encounters in Public",
#  "90's Toy Mystery Box (ft. Joe Sugg)",
#  'BTS Fans Get the Surprise of a Lifetime',
#  "Daisy Ridley talks about spending time with Carrie Fisher on the set of 'The Force Awakens'",
#  'John Mayer On Andy Cohen’s Annoying Habit | WWHL',
#  'COMING OUT (ELLE MILLS STYLE)',
#  '73 Questions With Michael B. Jordan | Vogue',
#  'This Week I Learned to Saber a Champagne Bottle',
#  'REACTING to BTS Mic Drop! (MV)',
#  '2018 Grammy Nominations ANNOUNCED - Kendrick Lamar, Jay-Z, Bruno & MORE',
#  'Kris Jenner would Love to Live with Kim Kardashian & Kanye West again',
#  'PADDINGTON 2 - Full US Trailer',
#  'A Magical Holiday',
#  'A Sainty Switch',
#  "Marvel Studios' Avengers: Infinity War Official Trailer",
#  'ALL THE MONEY IN THE WORLD - Official Trailer (HD)',
#  'All The Money In The World - TV Spot featuring Christopher Plummer',
#  'Kylie Jenner Pregnancy Reveal On Keeping Up With The Kardashians',
#  'Adriana Lima’s Victoria’s Secret Sleepover | Vogue',
#  'Joe Keery Swings By To Talk About Stranger Things 2',
#  'Armie Hammer and Timothée Chalamet Talk Passionate First Rehearsal',
#  'Honest Trailer Commentaries - The Room',
#  'John Mayer And Nicki Minaj’s Twitter Flirting | WWHL',
#  'Avengers 4: Who Will Die? - Movie Talk',
#  "'Riverdale' Season 2: Josie Takes Center Stage In The Upcoming 3 Part Episode | Sweetwater Secrets",
#  'Los Angeles’s Dangerous Obsession with Car Chases | The New Yorker',
#  "She's Gotta Have It | My Name Isn't | Netflix",
#  'Verizon Commercial 2017 - (USA)',
#  'Kelly Clarkson Carpool Karaoke',
#  'Justin Timberlake And Stephen Harmonize The National Anthem',
#  'James Franco Brings Tommy Wiseau to Kimmel',
#  '10 Crazy eBay Items!',
#  'Avengers: Infinity War - Trailer Review',
#  "Chelsea Handler Questions Whether She's Cut Out for a Relationship",
#  "Disney's Live Action Mulan - Liu Yifei aka Crystal Liu Cast - REACTION",
#  'I Pretended To Be A Model On A Shoot For Jigsaw',
#  "Magic MAGNETIC Nail Polish?!  (maybe don't wear metal)",
#  'Black Mirror - Black Museum | Official Trailer [HD] | Netflix',
#  'I Became My Sim For A Day *CHALLENGE*',
#  'THOROUGHBREDS - Official Trailer [HD] - In Theaters March 9, 2018',
#  'KUWTK | Kendall Jenner & Khloe Kardashian Consider Getting a Gun | E!',
#  "Twitter Is FURIOUS VS Fashion Show Aired Model's Runway Fall UNEDITED",
#  "At Home with Amy Sedaris - Amy's Not-So Holiday Special | truTV",
#  'Melania Trump Is Dreaming Of A Dark Christmas',
#  'Jimmy Kimmel on Twitter War with Roy Moore',
#  'YOUTUBERS REACT TO THEIR OLD YOUTUBE CHANNEL PROFILE #2',
#  '[2017 MAMA in Hong Kong] BTS_INTRO Perf. + Not Today',
#  'Black Mirror - Hang the DJ | Official Trailer [HD] | Netflix',
#  'Ed Sheeran on His Girlfriend and Working with Beyoncé',
#  'Flinch w/ BTS',
#  'Midnight Sun | Official Trailer | In Theaters March 23',
#  'Drop the Mic: Michael Bennett vs Vanessa Hudgens - FULL BATTLE | TBS',
#  'Crisis on Earth-X - Snart & The Ray Kiss',
#  '1,000,000 Dominoes Falling is Oddly SATISFYING',
#  'White House Christmas Cold Open - SNL',
#  'The Cast of Star Wars: The Last Jedi Has Mixed Feelings on Porgs',
#  'Jordan Peele Breaks Down Get Out Fan Theories from Reddit | Vanity Fair',
#  'YouTube Creators for Change: Natalie Tran | White Male Asian Female',
#  'Star Wars: The Last Jedi | Training Featurette',
#  'THE TOKYO STOMP (feat. Anna Akana)',
#  'Ashanti Speaks on Irv Gotti and Murder Inc | Everyday Struggle',
#  'Little Mix bring the Power & CNCO to The X Factor Final! | Final | The X Factor 2017',
#  'Black Mirror - Metalhead | Official Trailer [HD] | Netflix',
#  'DIY PIZZA POUCH & WEARABLE PIZZA',
#  'The Cast of Star Wars: The Last Jedi Talk Kylo Ren, Jedi Controversy, Harrison Ford & Secrets',
#  'Top 10 Strangest Things That Happen To Your Body In Space',
#  'Queen Biopic Stops Production, Avengers Fighting Alien Cannon Fodder Again - The John Campea Show',
#  'Prince Harry and Meghan Markle Get the Alison Hammond Experience! | This Morning',
#  'STAR WARS in Public',
#  'Joe Rogan and Eddie Bravo on Bob Sapp vs Nogueira (Part 1 of 2)',
#  'Jurassic World: Fallen Kingdom - Trailer Thursday (Run) (HD)',
#  'Ashanti Talks Murda Inc, Relationships, New Music + More',
#  'Thomas Train Stunts',
#  'Will It Christmas Tree?',
#  'Learn to Break a Glass with Your Voice || Learn Quick',
#  'Welcome to Hell - SNL',
#  'Alessandra Ambrosio’s Wax Sculpture',
#  "Xscape's Tamika Scott Falls During Epic Wardrobe Malfunction Onstage | TMZ",
#  'Tiffany Haddish Details Her Dinners with Barbra Streisand & Taylor Swift',
#  'Justice League Will Fail To Hit $700 Million At Box Office - Box Office Report',
#  'Testing Nail Products from Wish Nails Remove Toes Hollow Nail Polish Peel-off Nails Wish Buy Now',
#  'Billy Bush Believes The Women Accusing Trump Of Sexual Assault',
#  'Black Mirror - U.S.S. Callister | Official Trailer [HD] | Netflix',
#  "Chris Pratt & Bryce Dallas Howard's Kids Are BFFs",
#  'The Voice 2017 Keisha Renee - Top 10: All By Myself',
#  'Actors on Actors: Saoirse Ronan and Kristen Wiig (Full Video)',
#  "The Talk - Hilary Duff Dishes on Boyfriend Matthew Koma: 'third times a charm'",
#  'Morgan Freeman Hosts the Breakthrough Prize | Nat Geo Live',
#  '[2017 MAMA in Hong Kong] BTS_BTS Cypher 4 + MIC DROP(Steve Aoki Remix Ver.)',
#  'Vanderpump Rules: Lisa Confronts Sandoval for Talking Crap (Season 6, Episode 1) | Bravo',
#  'YouTube Rewind: The Shape of 2017 | #YouTubeRewind',
#  'Black Mirror - Season 4 | Official Trailer [HD] | Netflix',
#  "Saoirse Ronan Knows Why You Love 'Lady Bird'",
#  'Is Sam Smith Team Kim Kardashian Or Team Taylor Swift? | Plead The Fifth | WWHL',
#  'Grinch Holiday Humming Challenge (ft. Grace Helbig)',
#  '‘The Grand Tour’ Café',
#  'What Would A Quentin Tarantino Star Trek Movie Look Like? - SJU',
#  'Quentin Tarantino Developing New Star Trek Movie - Movie Talk',
#  'Glam Masters | Official Trailer | New Series Premieres February 28 at 10/9c | Lifetime',
#  'Outback Bowl is January 1st',
#  "Star Wars: The Last Jedi Cast on Carrie Fisher's Final Performance | E! Live from the Red Carpet",
#  "Saoirse Ronan says first-time movie director Greta Gerwig was born to do 'Lady Bird'",
#  'SNL Invisible Box Challenge',
#  "Kristen Wiig Struggles with 'Hallelujah'",
#  'Ramsay Shuts Down Restaurant After Finding RAW Chicken Next to Cooked Chicken! | Kitchen Nightmares',
#  "It's Day 12 of Ellen's 12 Days of Giveaways! Allison Janney Gets Dramatic with Ellen",
#  "Neil Patrick Harris' Guest Host Monologue on Jimmy Kimmel Live",
#  'WAGS Atlanta First Look | E!',
#  'I SNUCK INTO YOUTUBE REWIND 2017 (I was invited) | Behind The Scenes | NYC',
#  'After Show: Patti LaBelle’s Advice For Mariah Carey | WWHL',
#  'HOLIDAY MAKEUP LOOK',
#  'Riverdale | Mad World | The CW',
#  'GLOBAL BAN ON GLITTER!! THIS IS NOT A DRILL! The best day of my life!',
#  'Tank Has Words of Support for Tyrese',
#  'Why Avengers Infinity War Will Succeed Where Justice League Failed - The John Campea Show',
#  'Grown-ish (Freeform) College Parties Trailer HD - Black-ish spinoff',
#  'Best Carol Burnett Show Bloopers',
#  'The Real Reason Tyrese Married His Ex Wife',
#  'At Home with Amy Sedaris - Astronaut Relationship Jokes (ft. Justin Theroux) | truTV',
#  'Jurassic World: Fallen Kingdom - Official Trailer [HD]',
#  'Dude vs. Wild - Nevada Mountains',
#  'Take a Break: The Forum General Manager',
#  'Guest Host Melissa McCarthy Interviews Dave Franco',
#  'Gwen Stefani Talks Moving in with Blake Shelton',
#  'Sarah Paulson Has Twitchy Eye From 2017',
#  'Madonna and Anderson Cooper Play Sketching with the Stars with Kelly & Ryan',
#  'Claire Foy And Matt Smith’s Netflix And Chill Picks | WWHL',
#  'Mechanical LEGO Keyboard',
#  'The Flash | Deleted Scene | The CW',
#  "David Dobrik Crashes Liza and Gabbie's Q&A",
#  'YOUTUBERS REACT TO YOUTUBE REWIND 2017',
#  "Marvel's Jessica Jones | Date Announcement: She's Back [HD] | Netflix",
#  "Lost 'Star Wars' Footage Of Luke Skywalker At The Cantina",
#  'James Franco Audience Questions Monologue - SNL',
#  "Rebel Wilson's does her Pitch Perfect audition - The Graham Norton Show: 2017 - BBC One",
#  'SINGING MY MAKEUP ROUTINE (CHRISTMAS EDITION!)',
#  'How to Take Out AT-ATs - EASY METHOD EXPLAINED!!',
#  'Mamrie Hart Gets Under The Sheets on Collider Ladies Night',
#  "Danny Masterson Fired From Netflix Series 'The Ranch' Amid Rape Allegations | Access Hollywood",
#  'READY PLAYER ONE - Official Trailer 1 [HD]',
#  'Visit with Santa Cold Open - SNL',
#  'Bleach Blonde Baby Teaser',
#  'Live From The Red Carpet Of Star Wars: The Last Jedi',
#  'Mixing All My Nail Powders Together (for sale if u keep it on the DL)',
#  'James Franco Reads Bad Video Game Lines as Tommy Wiseau - Up At Noon Live!',
#  'ATTEMPTING EVERY 2017 TREND',
#  'Could Kevin Feige Save DC? Does Alita Battle Angel Look Great Or Terrible? The John Campea Show',
#  'Tiffany Haddish thanks her bullies for making her rich, forces George Stephanopoulos to dance',
#  'Cardistry - Virtuoso : RISE feat. the FW17 Virtuoso deck',
#  'New Yorkers Share their Story for a Dollar - Part 5',
#  'The Evolution of the Movie Trailer',
#  '3D Printed Monster Spitfire | FLITE TEST',
#  'The Quest for the Holy Grail Meets Parkour in Real Life In HDR 8K',
#  'Scott Disick Goes Sneaker Shopping With Complex',
#  'Logan Paul - SANTA DISS TRACK (Official Music Video)',
#  "The Last Jedi Cast Answers the Web's Most Searched Questions | WIRED",
#  '(SPOILERS) Mid-Season Finale Talked About Scene | The Walking Dead',
#  'Fuller House - Season 3B | Official Trailer [HD] | Netflix',
#  'Does Tiffany Haddish Think NeNe Leakes Is Funny? | RHOA | WWHL',
#  "Zendaya Talks About Zac Efron's Reaction to Their Onscreen Kiss",
#  "Jennifer Hudson Is Christmas' Biggest Fan",
#  'SPIDER-MAN: INTO THE SPIDER-VERSE - Official Teaser Trailer',
#  'REST IN PEACE ANGRY GRANDPA',
#  'Star Wars The Last Jedi First Reactions And World Premiere Report - The John Campea Show',
#  "We Tried The 2017 Victoria's Secret Model Diet For A Week",
#  'Best Videos of the Year 2017 | People Are Awesome',
#  'John Boyega Finn interview - Star Wars The Last Jedi Red Carpet World Premiere',
#  '7 DAYS IN ENTEBBE - Official Trailer [HD] - In Theaters March 2018',
#  'My Gender.',
#  'How to Hijack Amazon Prime Now for Good',
#  'Star Wars Cast Takes Which Star Wars Character Are You? Quiz',
#  'Dwayne Johnson Has Exciting Baby News!',
#  "Matt Damon Explains Why 'Good Will Hunting' Has So Much Cursing",
#  'Star Wars: The Last Jedi - Movie Review',
#  'How-To Make Chocolate Mousse with Matty Matheson',
#  'Jennifer Hudson: “Burden Down” - The Voice 2017',
#  "'Santa Claus Is Comin' To Town' Carpool Karaoke",
#  "Kids Interview The 'Star Wars: The Last Jedi' Cast With Daisy Ridley, Mark Hamill & More | PeopleTV",
#  'YouTuber Holiday Gift Wrapping (ft. Eva Gutowski & Kyle Krieger)',
#  'The Bachelor Returns Janu-Arie 1',
#  "Comedian Tig Notaro Says It's A 'Huge Relief' Louis CK Was 'Removed' From Comedy Industry | The View",
#  'Keaton Jones Why do they bully? POWERFUL MESSAGE',
#  "Star Wars: Luke's Journey To The Last Jedi",
#  'SPORCLE WORLD RECORD - Typing Every Country in Under 3 Minutes',
#  'Lavar Ball & Sons On Family Business, Discipline, Donald Trump + More',
#  'Tom Hanks And Stephen Argue Christmas Tree Technique',
#  'Anna Camp Takes the Bra Off Her Back for Anna Kendrick',
#  'The Last Jedi Cast Touches Bearded Dragons & Other Weird Stuff | Fear Box | Vanity Fair',
#  'Bleach Blonde Baby (Official Video)',
#  'Harry Styles to the Rescue!',
#  'The Last Jedi Cast Competes in a Compliment Battle | Teen Vogue',
#  'TWO SELENA GOMEZES MEET FOR THE FIRST TIME (FBE)',
#  "T-Mobile CEO John Legere | We're bringing the Un-carrier to TV",
#  'THE 15:17 TO PARIS - Official Trailer [HD]',
#  'Christmas Inheritance | Official Trailer [HD] | Netflix',
#  'Star Wars: The Last Jedi Review (SPOILER FREE)',
#  "'Wonder Woman' Director Patty Jenkins on Picking The Right Project | Close Up With THR",
#  'Stranger Things Actor Reveals MAJOR Hint About Season 3',
#  'Black Panther: New International Trailer Released - Movie Talk',
#  'Star Wars: The Last Jedi Review',
#  'Interview with Clarice Lispector - São Paulo, 1977 (English subtitles)',
#  'YOUTUBERS REACT TO INVISIBLE BOX CHALLENGE',
#  'Kevin Hart Lives His Truth And Opens Up About Being Irresponsible And More',
#  'Will Smith Watched His Sons Jump Out of an Airplane',
#  "We Demand $1 Fries on the New McDonald's Dollar Menu",
#  "The Late Show 'Rescue Dog Rescue' With Nick Jonas",
#  'Ayrton Little Was ACCEPTED INTO HARVARD UNIVERSITY AT 16 YEARS OLD!',
#  'Star Wars: The Last Jedi Cast Play WOULD YOU RATHER? | MTV Movies',
#  'I made him fabulous! | Best Friend Makeover Challenge with boyinaband',
#  'Mixing All My Tea Together *warning: some tea was spilled*',
#  "Tamar's Executive Decision | Tamar & Vince | WE tv",
#  "i have a condition that makes me feel like i'm dreaming all the time",
#  'Netflix Is Trolling Its Viewers And We Love It - SJU',
#  'The Last Jedi Cast Answers YOUR Questions, Behind the Scenes of the Red Carpet Live Stream, & More!',
#  "THE WORLD'S HARDEST SCOOTER TRICK!",
#  'Disney Officially to Buy 21st Century Fox for $52.4 Billion - IGN News',
#  '17 of 2017: The Year in Pop Culture (ft. Damon and Jo) | Kingsley',
#  "'Riverdale' S2E09 'Silent Night, Deadly Night' PRESHOW | Sweetwater Secrets",
#  'Matt Damon and the Hemsworth Brothers Run into Ryan',
#  'Jaguar vs. Caiman | Big Cat Week',
#  'Crosswalk the Musical on Broadway (w/ Hugh Jackman, Zendaya & Zac Efron)',
#  "Adam Driver And Stephen Act Out A 'Star Wars' Scene Using Dolls",
#  'RECREATING OUR FAVORITE VINES!',
#  'Will Smith Asks Strangers for Money',
#  '4 Ton Wrecking Ball in Slow Motion - The Slow Mo Guys',
#  "John Cena Answers the Web's Most Searched Questions | WIRED",
#  'The Polka King | Official Trailer [HD] | Netflix',
#  "Giving my 13 year old niece the 'emo phase'",
#  'I Trained Like Rey From Star Wars For A Month ⚔️',
#  'Riverdale | Chapter Twenty-Three: The Blackboard Jungle Trailer | The CW',
#  '“Santa Baby” ft. Ciara | TARAJI’S WHITE HOT HOLIDAYS',
#  'WOODY WOODPECKER Trailer #1 NEW (2018) Live Action Comedy Movie HD',
#  'How Noah Galvin Makes Evan Hansen His Own',
#  "Clarice Probes Hannibal Lecter About Trump's Russia Ties",
#  'My skincare routine',
#  'Chris Brown , Cardi B , Lil Kim , Remy Ma , Yo Gotti Live Hot 97 Hot For The Holidays Concert 2017',
#  'Star Wars: The Last Jedi Will Have a MASSIVE Opening Weekend - SJU',
#  'Star Wars The Last Jedi - Which Audience Score Should We Believe?',
#  'Do You Want to Hear a Woke Eminem? | Everyday Struggle',
#  'White House Tree Trimming Cold Open - SNL',
#  'PANCAKE ART CHALLENGE 4!!! Learn How To Make Mario Odyssey Star Wars Jedi Nintendo Food DIY Pancake',
#  'Gucci Gang Country Edition! (Dear Ryan)',
#  'YOUTUBERS REACT TO TOP 10 VEVO CHANNELS OF ALL TIME',
#  'Jack Black | This Week on GMM',
#  'Introducing Communist Amazon Echo',
#  'Is Andy Cohen Or Anderson Cooper More Kinky In Bed? | WWHL',
#  "You'll Shoot Your Eye Out Performance | A CHRISTMAS STORY LIVE",
#  'DIY Snowglobe Nails (I built a snowman on my nail)',
#  'TRYING ON ENGAGEMENT RINGS (no proposal)',
#  'Mark Hamill Didn’t Tell Carrie Fisher the Big Star Wars Secret | The Graham Norton Show',
#  'What Happens If You Fill Up a Car with Coca-Cola?',
#  'ATTEMPTING HOLIDAY LIFE HACKS',
#  'Star Wars The Last Jedi Scores An A Cinemascore And 2nd Largest Opening Ever - The John Campea Show',
#  'John Boyega and Oscar Isaac Read Hilarious Thirst Tweets',
#  "The Voice 2017 Chloe Kohanski - Finale: “Wish I Didn't Love You”",
#  'Mortal Engines Official Teaser Trailer [HD]',
#  "OCEAN'S 8 - Trailer Teaser",
#  'The Shape of Water - Movie Review',
#  'Keeping Up With the Kardashians Katch-Up S14, EP.11 | E!',
#  'STAR WARS THE LAST JEDI - Movie Review (Black Nerd)',
#  'Star Wars: The Last Jedi Spoiler Review And Discussion PART 1',
#  '24 STRINGS BASS SOLO... AGAIN',
#  'Small Details You Missed In The Last Jedi',
#  'TESTING KYLIE $360 BRUSH SET VS MORPHE DUPES',
#  "OCEAN'S 8 - Official 1st Trailer",
#  "It's true, wife and I are getting a divorce.  Here's whats next for us.",
#  'CHRISTMAS BOOTY SONG',
#  'The Voice 2017 Chloe Kohanski and Billy Idol - Finale: White Wedding',
#  'SICARIO 2: SOLDADO - Official Teaser Trailer (HD)',
#  'Step Up: High Water | OFFICIAL TRAILER',
#  'Narcos - Season 4 | Teaser [HD] I Netflix',
#  'Sesame Street Puppeteers Explain How They Control Their Puppets | WIRED',
#  'Thank You Peter Capaldi | Doctor Who Christmas | Christmas Night @ 9/8c on BBC America',
#  'FORGING A DAMASCUS ANVIL!! Part 2',
#  "Simply Nailogical's Holoday Hits 2017",
#  'Star Wars: The Last Jedi Has Second Largest Opening Ever Amidst Mixed Fan Reactions - Movie Talk',
#  'Weekend Update on Doug Jones Defeating Roy Moore - SNL',
#  'Is The Last Jedi the Most Divisive Star Wars Movie Ever? (SPOILERS) - SJU',
#  'Why Imperial Admirals had High Suicide Rates [Canon] - Star Wars Explained',
#  'The Voice 2017 - The Season 13 Voice Champion Is...',
#  'Bedtime with Babish: A New Podcast',
#  'Star Wars: The Last Jedi | Becoming Rose',
#  'Grace and Frankie - Season 4 | Official Trailer [HD] | Netflix',
#  'Music is Magic',
#  'Star Wars Episode IX Story Pitched By JJ Abrams - Movie Talk',
#  'Why the Holidays Ruin Friendships',
#  'Ralphie To The Rescue Performance | A CHRISTMAS STORY LIVE',
#  'The Great Festive Bake Off does Stay Another Day | The Great British Bake Off',
#  'Still to Come this Season on Keeping Up With the Kardashians | E!',
#  'James Franco Reads Mind-Blowing Philosophy Quotes as Tommy Wiseau | Vanity Fair',
#  'Christian Bale, Rosamund Pike & Wes Studi Speak On Hostiles',
#  'Mamma Mia! Here We Go Again - Trailer',
#  'Cut for Time: Hallmark Channel Christmas Promo (James Franco) - SNL',
#  '73 Questions With Gina Rodriguez | Vogue',
#  'DIY GIANT SWISS ROLL - VERSUS',
#  "Impossible Rubik's Cubes",
#  'Foot Locker x Jordan - “#BoldLikeKawhi” feat. Kawhi Leonard',
#  'Khloe Kardashian Confirms Pregnancy & Reveals Baby Bump | Hollywoodlife',
#  "I'm Not A Child, I'm 20 | Living Differently",
#  "Will Smith & Joel Edgerton Answer the Web's Most Searched Questions | WIRED",
#  'Seven Seconds I Teaser [HD] I Netflix',
#  'K-pop stars carry Jonghyun’s coffin after suicide',
#  'Count On Christmas Performance ft. Bebe Rexha | A CHRISTMAS STORY LIVE',
#  'YOUTUBERS REACT TO TOP 10 YOUTUBE VIDEOS OF 2017',
#  'FULL FACE OF YOUTUBER CHRISTMAS PRESENTS',
#  'Clarabelle Flirted with Me?! - Disneyland Impressions',
#  'The Rock’s Make a Wish Surprise',
#  'Kate Winslet Commits to Her Ugly Christmas Sweater Look',
#  'Becoming Plum with Sarah Lamb',
#  'Christian Bale: Division Is Not The Way To Go',
#  'COLLEGE KIDS REACT TO K-POP (BTS, MONSTA X, SEVENTEEN, TWICE, Red Velvet)',
#  'Merry Christmas in Dominoes! 🎅🏻 (Christmas Card)',
#  'How Fleetwood Mac Makes A Song',
#  'FULL STREAM | Real Madrid - FC Barcelona warm-up #ElClásico',
#  "Margot Robbie: How Hollywood's Horrible Situation Brings Actresses Together | Close Up With THR",
#  'Real Madrid players warm up before the Clásico!',
#  'Hugh Jackman On Keeping His 21-Year Marriage Strong: The Crazy Ups & Crazy Downs | PeopleTV',
#  'The Path Season 3 Trailer (Official) • The Path on Hulu',
#  'PART 1 | Gwen Stefani with Blake Shelton | Instagram | December 24, 2017 | Christmas Eve with family',
#  'The 75th Annual Golden Globes - There’s a Lot to Talk About! (Promo)',
#  "Jonathan Groff's Festive Christmas Sweater",
#  'Koala Brawl : Koalas Fight on Australian Road - Near Adelaide',
#  'The Twelfth Doctor Regenerates: Peter Capaldi to Jodie Whittaker - Doctor Who Christmas Special 2017',
#  'Home for the Holidays',
#  'SPOILERS! The Twelfth Doctor Regenerates – Peter Capaldi to Jodie Whittaker - Doctor Who - BBC',
#  'PADDINGTON 2 -  US Trailer 2',
#  'Lying on a $150K Bed Made of Horse Hair',
#  'Top 10 WORST Movies 2017',
#  'Drop the Mic: Pentatonix vs Bell Biv Devoe - FULL BATTLE | TBS',
#  'The Assassination of Gianni Versace: American Crime Story | Season 2: First Look | FX',
#  'Wizards of Waverly Place: The Movie - Disneycember',
#  'Binging with Babish: The Wire Special',
#  'Hot Wheels in the Garden',
#  'Lauren London Goes Sneaker Shopping With Complex',
#  'The Open House | Official Trailer [HD] | Netflix',
#  'DIY RUGRATS REPTAR BAR - FEATURING REPTILES',
#  'Charlamagne Tha God & Joe Budden Present: This Year Was Dope/Trash 2017 (Full Episode)',
#  "Alien Covenant Sequel Cancelled? Mark Hamill's Opinion Of The Last Jedi - The John Campea Show",
#  "Michelle Williams Recalls Being Mistaken for the Destiny's Child Singer at a Concert (Exclusive)",
#  'I THREW MY CRUSH HER OWN PROM',
#  'Zac Efron Made Michael Jackson Cry! | The Graham Norton Show',
#  '2017 KBS가요대축제 Music Festival - 방탄소년단 - DNA (DNA - BTS). 20171229',
#  'The Royals New Season First Look | E!',
#  'star wars || war pigs',
#  'Best of Hevesh5 (8)',
#  'BLANK CANVAS... 2017 YEAR IN REVIEW',
#  'Animal electricity - Fingerling Fart Monkey Teardown',
#  '1982 TOYOTA COROLLA Ad',
#  "Ryan Seacrest dishes on New Year's Eve, 'American Idol'",
#  'The End of the F**king World | Official Trailer [HD] | Netflix',
#  'Karl Pilkington predicts Black Mirror (spoilers)',
#  'LUKE SKYWALKER vs. KYLO REN 16 Bit',
#  'Fifty Shades Freed - Mrs. Grey Will See You Now [HD]',
#  'So Sorry.',
#  'Ellen Cooks Up a Huge Surprise for Food Critic Kalen Allen!',
#  'I Gave Myself A Kim Kardashian Hair Makeover 💇',
#  'Shaving my mustache!!!',
#  'Paris Hilton ENGAGED to Chris Zylka!',
#  "What's in my Peely Bag? (Re-creating 5 of my nail peelies) / 2017 year-in-review",
#  'The 77 Year Old Ballet Dancer Sharing Seven Decades Of Experience | Amazing Humans',
#  "It's not easy to be a tram driver.",
#  "Danielle Bregoli Rejects Logan Paul's Apologies Over Suicide/Hanging Video | TMZ",
#  'SLENDER MAN - Official Trailer (HD)',
#  "Anderson Cooper Walked Out Of The New 'Star Wars' Movie",
#  "Blumhouse's Truth or Dare - Official Trailer [HD]",
#  "'The Four' Cast Plays 'Never Have I Ever'",
#  'Bright | Leaked Orc Auditions Confirm Sequel Rumors | Netflix',
#  'Jodie Foster Says Big Budget Films Ruin Viewing Habits - Movie Talk',
#  'BTS Special / 방탄소년단 스페셜 [2017 KBS Song Festival | 2017 KBS 가요대축제 / 2017.12.29]',
#  'Everything Ellen Knows About #DeepState and Eric Trump',
#  "America Ferrera's Busy 2018: Pregnancy And The 'Time's Up' Movement",
#  'Volatile Owner Tears into Customer Over Microwaved Lamb | Kitchen Nightmares',
#  "Jessica Chastain's Italian In-Laws Might Hate Her",
#  'One Thing Arnold Schwarzenegger Told Me That I’ll Never Forget | Will Smith Vlogs',
#  'Disney Resort Tour | Yacht & Beach Club Resort Hotel Grounds Tour, Pool Locations & More!',
#  "Laura Govan Addresses Rumors Of Pregnancy & Affair With Vincent Herbert: He's So Not My Type",
#  "Tamar Braxton Ex's Alleged New Fling Laura Govan Speaks Out | Daily Pop | E! News",
#  'My big problem with the iPhone X',
#  'Tesla Model 3 First Drive and Impressions | Neat Stuff in Cool Cars',
#  'My Next Guest Needs No Introduction With David Letterman | Trailer [HD] | Netflix',
#  'Khloé Kardashian Reveals Pregnancy & Delivery Details',
#  'WINCHESTER - Official Trailer - HD (Helen Mirren, Jason Clarke)',
#  'BEST OF 2017 - Black Nerd RANTS',
#  "ESPN's Katie Nolan (Extended Cut)",
#  'Box Office Winners and Losers of 2017 - Movie Talk',
#  '[FULL STREAM] Open doors training session',
#  "Michael Jackson's Dont Stop Till You Get Enough - By Jay",
#  'Inventing The Wheel',
#  'Dazed & Confused - LIVIN Speech',
#  '#DisneyParksLIVE: Fantasy In The Sky New Years Eve Fireworks | Disney World',
#  'OUR LIT NEW YEARS EVE!!',
#  'NERF Putt-Putt Golf Challenge!',
#  'JuJu Smith-Schuster Pranks Steelers Fans - Undercover News Interview',
#  'Meet the new Sugar Pine 7.',
#  'Billions Season 3 (2018) | Official Trailer | Damian Lewis & Paul Giamatti SHOWTIME Series',
#  'Daz Watches Worst Kickstarters #9',
#  'Whole ocean is frozen, INSANE!',
#  'Oprah Winfrey Receives Cecil B. de Mille Award at the 2018 Golden Globes',
#  'Gateway to Sedona DEBUNK',
#  'Golden Globes 2018: What to Expect as Celebs Hit the Red Carpet in All Black',
#  'The Mystery That Keeps Neil deGrasse Tyson Up At Night',
#  'Reacting to My First Video (try not to cringe compilation)',
#  'iPhone X vs 100 Tide Pods EXPERIMENT - Will it Survive?',
#  'Checking Out the New McDonald’s Dollar Menu',
#  '2018 Golden Globes: Who Should Win, Who Will Win | THR',
#  '10 BEST Moments From 2018 Golden Globes',
#  'Will It Meatloaf? Taste Test',
#  "Matty Matheson Reviews The Internet's Most Popular Food Videos | Bon Appétit",
#  'Oprah Winfrey - 2018 Golden Globes - Full Backstage Speech',
#  'Golden Globes 2018: The Most Memorable Moments | THR News',
#  "Marvel Studios' Black Panther - Rise TV Spot",
#  'Emma Watson Attends Golden Globes With Imkaan Activist | E! Live from the Red Carpet',
#  'KUWTK | Katch the Two Night Kardashian Event this Sunday and Monday | E!',
#  '1 MILLION SUBSCRIBER WATCH PARTY',
#  "Logan Paul (Don't be That Guy in Japan... or Anywhere Else)",
#  'Matthieu Ricard Leads a Meditation on Altruistic Love and Compassion | Talks at Google',
#  'Golden Globes Movie Predictions - Collider Scoreboard',
#  'Cantina Theme played by a pencil and a girl with too much time on her hands',
#  'TULLY - Official Teaser Trailer - In Theaters April 20',
#  'Altered Carbon | Official Trailer [HD] | Netflix',
#  'Sarah Jessica Parker Finally Gets Asked To Prom',
#  'Kids Try 100 Years of the Most Expensive Foods | Bon Appétit',
#  'Tonya Harding Cuts Interview Short | The View',
#  'Chris Hemsworth Reveals Where He Keeps His Hammer',
#  "Dame Helen Mirren Finds Out She's Only 72 Years Old",
#  'DIY STUDY HACKS! How To Be PRODUCTIVE After School + Study Tips to Get BETTER GRADES!',
#  'Clip: Why President Obama stays in the pocket with his dad moves [HD] | Netflix',
#  "KUWTK | Khloé Kardashian Sees the Positive in Rob & Chyna's Drama | E!",
#  'Lena Waithe is Winning',
#  "Camila Cabello Loves Ikeas's Meatballs | Elvis Duran Inteview Highlight",
#  'Flower (2018) | Official US Trailer HD',
#  'Venom:  Tom Hardy Full Brazil Comic Con Panel - IGN First',
#  'Charlamagne Defends Ginuwine After Being Labeled Transphobic By Twitter Stampede',
#  'When Your Catfish Is Actually a Fish (w/ Sally Hawkins)',
#  'Match the Dog to Their Owner - Lineup',
#  'Marbles, Magnets, and Music (Synchronized)',
#  'Westworld - Season  1 Review',
#  "Riverdale's Casey Cott Reviews Riverdale Memes | Teen Vogue",
#  'ORGANIZE | Garage Clean Out! (and where to take stuff)',
#  'Gerard Butler le declara su amor a Ana Patricia en vivo',
#  'Trust | Season 1: Official Trailer [HD] | FX',
#  'Trying The FRUITARIAN Raw Vegan Diet For A Week 🍎🍌🍍',
#  "What's In Jeanine Amapola's Bag | Spill It | Refinery29",
#  'Keri Hilson Has Emotional Meeting with Psychic Medium Reginald Lewis',
#  'Rebel Wilson HEART RATE MONITOR (feat. Hugh Jackman)',
#  'Rich Brian Goes Sneaker Shopping With Complex',
#  'CRUISE SHIP CAUGHT IN A BOMB CYCLONE (Norwegian Breakaway)',
#  'Blockers - Official Trailer (HD)',
#  "The Weeknd BLASTS H&M Over Racist 'Monkey' Ad Featuring Black Child, ENDS Partnership",
#  'Things Not To Say To Single Parents',
#  'Jennifer Lopez and Alex Rodriguez bring hope and relief to storm-ravaged Puerto Rico',
#  'Our Cartoon President (2018) | Official Trailer | Stephen Colbert SHOWTIME Series',
#  'Robot Writes New Harry Potter Chapter',
#  "World's smallest cat - Big Cats: Preview - BBC One",
#  'G-Eazy On Stepping Away From H&M, Being A Crazy Gemini, Halsey & More',
#  "Marvel Studios' Black Panther - Warriors of Wakanda",
#  'Helen Mirren, Donald Sutherland Talk Oscars Honor, #TimesUp Movement, Golden Globes & More',
#  'Ellen Pays Tribute to Her Late Father',
#  'Sam Rockwell, Not Halsey, Won a Golden Globe - SNL',
#  'HOW I BECAME A MAKEUP ARTIST with pictures',
#  'Camila Cabello Performs - Never Be the Same - GMA LIVE',
#  'We found the real Maui!!!',
#  'Kyrie Irving on Conspiracy Theories, Tightening His Handle, and Going to the Celtics (Ep. 4)',
#  'THINGS THAT ARE LOWER',
#  'PANDAS - OFFICIAL TEASER [HD]',
#  'Log Cabin TIMELAPSE Built By ONE MAN In The Forest (Real Life Minecraft)',
#  'Why Ikea wants you to pee on this ad',
#  'Alex, Inc. - Official Trailer',
#  '300,000 Dominoes FALLDOWN - Turkish Domino Record! (Pt. 2)',
#  "FULL STREAM | Yerry Mina's unveiling as a Barça player",
#  'Bird photobombs weather report',
#  'Black Mirror | Featurette: Season 4 | Netflix',
#  'Morning Joe Michael Wolff Cold Open - SNL',
#  'The Handmaid’s Tale Season 2 First Look (Official) • Only on Hulu',
#  'I Bought One Snickers Bar From Every Walmart',
#  'DIY 5 POUND POTATO SKIN - JULIA LEFT JP',
#  'DIY Maple Taffy on a Stick (is Canada even real?)',
#  'Making a Lemon Stun Gun',
#  'Can Porcupine Quills Puncture an iPhone X?',
#  'EXCLUSIVE: Reginae Carter Reveals What Changed After That Beef with Khia',
#  'Human Flaming Hot Cheeto Challenge',
#  "Cantina Theme Played By Rubik's Cube Whilst Being Solved | Pencil Girl Parody",
#  'Seeing Allred | Official Trailer [HD] | Netflix',
#  'Why are Koreans so obsessed with Bitcoin/Cryptocurrency?',
#  "Grey's Anatomy 14x09 Promo 1-800-799-7233 (HD) Season 14 Episode 9 Promo",
#  'Melissa Benoist Reveals Best Part About Playing Supergirl',
#  'Everything Sucks! | Date Announcement [HD] | Netflix',
#  'Penelope Cruz Tries to Teach Ellen Spanish',
#  'Keeping Up With the Kardashians Katch-Up: S14, EP.14 | E!',
#  'Kim Kardashian and Kanye West Welcome Baby Girl Via Surrogate I TMZ News',
#  '1992 Skin Bracer commercial w/Jack Palance',
#  "Adam & Bree's Story | How Couples Sleep",
#  'Where are we?',
#  "Learn to Juggle 5 Balls in 1 Month || Max's Monthly Challenge",
#  '21 Strangest Movie Translations in Japanese',
#  'Blade Vs Deacon Frost [Lightsaber Battle]',
#  'ASMR Lushful Spa Treatment ✨ Facial and Massage',
#  "Daniel Kaluuya: 'Get Out' Shows How White People Say Weird Stuff",
#  'Queer Eye | Official Trailer [HD] | Netflix',
#  'See With Your Ears: Spielberg And Sound Design',
#  "KUWTK | Kourtney Kardashian Explains Ex Scott's Reaction to Her BF | E!",
#  'Jimmy Kimmel Goes Undercover on Reddit, Twitter & Wikipedia | Actually Me | GQ',
#  'Nick Jonas HEART RATE MONITOR feat. Selena Gomez, Joe Jonas & Jack Black | STRONG LANGUAGE!',
#  'Did Kyle Richards See Kylie Jenner’s Baby Bump? | RHOBH | WWHL',
#  "Sarah Jessica Parker Wants Ellen to Play Samantha in the 'Sex and the City' Movie",
#  'KIND Presents: Anna Faris Reads Competitor Protein Bar Reviews',
#  'WHAT TO LEAVE IN 2017',
#  'Garry Kasparov Answers Chess Questions From Twitter | Tech Support | WIRED',
#  "WON'T YOU BE MY NEIGHBOR? - First Look Clip - Coming Soon",
#  'See 130 Years of National Geographic Covers in Under 2 Minutes | National Geographic',
#  'I Am MLK Jr. Official Teaser | Paramount Network',
#  'How a TV Works in Slow Motion - The Slow Mo Guys',
#  'Heathers Official Red Band Trailer | Premieres March 7th on Paramount Network',
#  'We have the EXCLUSIVE Super Troopers 2 trailer drop here and MEOW!',
#  "Saoirse Ronan Plays 'Who'd You Rather?'",
#  "Ricky Gervais: Hosting The 2018 Golden Globes Would've Ended My Career",
#  'Is Angelina Jolie Or Jennifer Aniston The Better Kisser? | Plead The Fifth | WWHL',
#  'NERF Pick Your Path Challenge!',
#  "70's Ads: After Eight Chocolate Mints",
#  'BLACK LIGHTNING - Series Premiere Review (Black Nerd)',
#  'Den of Thieves | Alpha Males Featurette | Now Playing',
#  "I've been shitposting a lot of memes lately",
#  'Will the Flash Movie (Flashpoint) Be Too Comedic in Tone? - Movie Talk',
#  'Inside Issa Rae’s LIT Malibu Pool Party! (Part 1/2)',
#  "Timothée Chalamet Donates Woody Allen Movie Salary To Time's Up | News Flash | Entertainment Weekly",
#  "Dakota Fanning dishes on new psychological thriller 'The Alienist'",
#  "Wanna Be Startin' Somethin' w/ the Stars! | Lip Sync Battle Live: A Michael Jackson Celebration",
#  'Jamie Dornan Had an Awkward ‘James Bond’ Moment | The Graham Norton Show',
#  'Adam Levine Almost S**t Himself While His Wife Was in Labor',
#  'Sharon Stone Is Proof That Women Can Play Roles Written For Men',
#  "Diddy Speaks On New Energy, 50 Cent, Mase, 'The Four' + More",
#  'Goodbye 3 Million Subscribers',
#  "Melania Trump Sings 'Part of Your World' (Little Mermaid Parody)",
#  "'Winchester' Clip Shows Spooky House in Helen Mirren's Haunting New Movie",
#  'Rita Ora - Proud (Official Audio)',
#  'CHIT CHAT GRWM WITH WINNIE HARLOW',
#  'Ikigai: The Japanese secret to a long and happy life',
#  'ELDERS REACT TO UGANDAN KNUCKLES MEMES',
#  'Helen Mirren Reunited with Ex-Boyfriend Liam Neeson | The Graham Norton Show',
#  'Jessica Chastain Monologue - SNL',
#  'What Even Matters Anymore - SNL',
#  'READY PLAYER ONE - See The Future',
#  'This Is Us: Press Room Q&A | 24th Annual SAG Awards | TNT',
#  'Magic Transforming Top Coat?! (does this thing even work)',
#  'Sean “Diddy” Combs On Janet Jackson And Justin Timberlake | WWHL',
#  "Scarlett Johansson Women's March Event Full Speech 2018 James Franco Natalie Portman",
#  'Getting WIDE Like Kylo Ren',
#  '50 Cent Goes Undercover on Reddit, Twitter & Instagram | Actually Me | GQ',
#  "Taye Diggs Slays 'Candyman' in Front of Christina Aguilera | Lip Sync Battle Preview",
#  '10 BEST Moments From 2018 SAG Awards',
#  'Frances McDormand: Acceptance Speech | 24th Annual SAG Awards | TNT',
#  'Quentin Tarantino’s Star Trek (Nerdist Presents)',
#  'DIY JAPANESE FLUFFY PANCAKES',
#  'Olivia Munn & Niecy Nash Hilariously Stole The Show At The 2018 SAG Awards | Access',
#  'Keeping Up With the Kardashians Katch-Up S14, EP.15 | E!',
#  'M&M’s Super Bowl Teaser 2018 (featuring Danny DeVito) :15',
#  '5 Things You Missed at the 2018 SAG Awards | E! News',
#  'The Breakfast Club Addresses Backlash After Amara La Negra Interview',
#  'Why Are Fat People a Joke?',
#  'Corden On Trump: I Spanked Him',
#  'How to Become TripAdvisor’s #1 Fake Restaurant',
#  "I'm Poppy - Trailer",
#  'GIVING AWAY MY YOUTUBE ADSENSE',
#  'Beyond the Routine: Jordyn Wieber - The Trailer',
#  'Burger King | Whopper Neutrality',
#  'Aaron Paul Reveals What NOT to Say to Your Wife During Labor',
#  "Marvel Studios' Black Panther - Kinetic Energy Film Clip",
#  'Seven Seconds | Official Trailer [HD] | Netflix',
#  'Christina Aguilera Watches Erika Jayne Crush “Fighter” | Lip Sync Battle',
#  'Skittles ))) Possible Super Bowl Ad – Sandwich',
#  "Maisie Williams HEART RATE MONITOR feat. Eddie Redmayne | GAME OF THRONES SEASON 8 'SPOILERS' (!?)",
#  'OUR FAMILY. #MYCALVINS: Kardashian / Jenner',
#  'Entire Breaking Bad Series in 1 Minute',
#  'How NOT to sexually harass someone - The Mash Report - BBC Two',
#  'John Varvatos Spring/Summer 2018 Campaign Featuring Nick Jonas #JVxNJ',
#  'Idris Elba thinks the world is ready for a black James Bond',
#  'Pantry Essentials | Basics with Babish',
#  "Are Taco Bell's Nacho Fries Worth the Hype?",
#  'KFC | Honky Tonk | Smoky Mountain BBQ',
#  'Lisa Kudrow is Handling Her Son Going to College Very Well',
#  'RuPaul And Stephen Share A Secret Language',
#  "Groupon 2018 Super Bowl Commercial | Who Wouldn't",
#  '#PepsiHalftime Choreography BTS | Justin Timberlake | Pepsi',
#  'Hollywood Stunt Falls in Slow Motion',
#  'THE GHOST IN MY HOUSE - Morgan Adams',
#  'The Last Jedi Novelization to Feature Deleted Scenes, Star Wars Day at Sea, and More!',
#  'Just a Couple Friends - Acoustic (MUSIC VIDEO)',
#  'How-To: Make a Deadliest Catch Pineapple Bowl with Trap Kitchen',
#  'Steve Brown Says Attacker Was Laughing Before He Stormed Stage | TMZ',
#  'MTB Skills - Technical Climb',
#  'ATV attempt to pull out the car ││ Any Rubbish',
#  'Running Through Glass in Slow Motion',
#  'Footage of how Tom Cruise broke his ankle while filming his latest movie - The Graham Norton Show',
#  "Stephen's Covetton House Meets Gwyneth Paltrow's Goop",
#  'Momsplaining with Kristen Bell #KidsPartyGoals, Ep. 2',
#  "Viola Davis on Melania Trump's Love of How to Get Away with Murder",
#  'Chloe Grace Moretz on Louis C.K. and the #MeToo movement',
#  'The Hurricane Heist Trailer',
#  'James Corden Almost Named His Daughter Beyoncé',
#  'Tom Cruise Shows Slow-Mo Footage of How He Broke His Ankle | The Graham Norton Show',
#  'The Ritual | Official Trailer [HD] | Netflix',
#  "'Call Me by Your Name' star Timothee Chalamet on the time he embarrassed himself with Saoirse Ronan",
#  'Skittles ))) Possible Super Bowl Ad – Floating',
#  'Kendrick lamar / U2 / Dave Chappelle  - XXX / DNA Grammy 2018 Performance',
#  'George W. Bush Returns Cold Open - SNL',
#  "James Corden Leads 'Subway Karaoke' During The 2018 GRAMMY Awards",
#  'THIS BRA MAKES YOU STRONGER! (Weird As Seen on TV Procucts)',
#  'Mamma Mia! Here We Go Again - Grammys Spot',
#  "John Legend And Tony Bennett Sing 'New York, New York'",
#  'Budweiser 2018 Super Bowl Commercial | “Stand By You”',
#  'Cardi B wants a Grammy',
#  "PJ Morton First Began 'Official Music Video'",
#  'Hillary Clinton, Cardi B & More Audition for Fire & Fury - 2018 GRAMMYs',
#  'Cardi B Has Butterflies in Her Stomach & Where?! | E! Live from the Red Carpet',
#  'When We First Met | Official Trailer [HD] | Netflix',
#  'Kesha Performs Praying at 2018 Grammys',
#  'Nicole Kidman Eats Bugs | Secret Talent Theatre | Vanity Fair',
#  'The BIGGEST Moments From the 2018 Grammys: Kesha, Bruno Mars, Kendrick Lamar, & Hillary Clinton',
#  'Fifth Harmony’s Ally Brooke is Selena AND J-Lo | Lip Sync Battle',
#  'WWE Royal Rumble 2018 Review: What Went Down?',
#  'I THREW MYSELF A GRADUATION CEREMONY',
#  'Did Alexa Lose Her Voice? - Teaser - Amazon Super Bowl Commercial LII',
#  'Inside The Littiest Pre-GRAMMY Party!',
#  "Marvel Studios' Ant-Man and the Wasp - Official Trailer",
#  'What Does a Giant Monster Neodymium Magnet do to a Mouse?',
#  'Childish Gambino Gives SOULFUL Terrified Performance At 2018 Grammys',
#  'Shinsuke Wins Rumble | Reaction | WWE Royal Rumble',
#  'This Is Us 2x14 Promo Super Bowl Sunday (HD)',
#  "Stephen Goes Live After Trump's State Of The Union",
#  'Drop the Mic w/ Helen Mirren',
#  'My therapist, Dr. Plier',
#  'The First Purge Announcement - In Theaters July 4',
#  'Kerry Washington on Scandal, Oprah & State of the Union',
#  'Universal Studios For Celebration Of Harry Potter Expo 2018 | WB Studio Tour, Movie Props & More!',
#  'Glee Star Mark Salling Dead of Apparent Suicide | TMZ News',
#  'DORITOS BLAZE vs. MTN DEW ICE | Super Bowl Commercial with Peter Dinklage and Morgan Freeman',
#  "Megan Mullally Didn't Notice the Interesting Pattern with Ellen's Roommates",
#  'SPOILER ALERT! 🌹🏁 Krystal, Will You Accept This Ride? | The Bachelor Insider',
#  'Keith Urban - Female Acoustic',
#  'M&M’S Super Bowl Commercial 2018 (featuring Danny DeVito) – ‘Human’ :30',
#  'Saved By The Max LA Ticket Announcement!',
#  "*SPOILER* 1st Eliminated Queen RuPaul's All Stars 3: Behind the Scenes",
#  'Michelle Obama Talks with Birthday Girl Ellen About Post-White House Life',
#  'Alexa Loses Her Voice – Leslie Jones and JB Smoove - “calling Ashley”',
#  'Melania Trump Gives Her Own State Of The Union',
#  'Shopping For Jugs | Growing Up Hip Hop: Atlanta | WE tv',
#  'Jamie Dornan on His Wee-Bag & Dakota Johnson',
#  "Lisa Kudrow Heard Lindsay Lohan Wants to Do 'The Comeback'",
#  'Riverdale | Chapter Twenty-Six: The Tell-Tale Heart Trailer | The CW',
#  'Sharon Stone As SATC’s Samantha Jones? | WWHL',
#  "Jim Gaffigan Hijacks a Stranger's Tinder | Vanity Fair",
#  'Mr. Bean Is A Master Of Physical Comedy',
#  'DORITOS BLAZE vs. MTN DEW ICE | Super Bowl Commercial with Peter Dinklage and Morgan Freeman',
#  "Fifth Harmony’s Normani Kordei Performs 'Bootylicious' by Destiny's Child  | Lip Sync Battle Preview",
#  'The Moment George Clooney Met Amal | My Next Guest Needs No Introduction | Netflix',
#  'When Will We See The X-Men In the MCU? - SJU',
#  'Ant-Man and The Wasp Trailer Drops + Black Panther First Reactions - Movie Talk',
#  'Quick D: Invisible Box Challenge',
#  "BREAKING: Meek's Lawyer Fires Back With Proof Judge Favored Old Management",
#  "Logan Paul Says He's Still Learning From Suicide Forest Mistake | TMZ",
#  'Tom Clancy’s Jack Ryan – Super Bowl Commercial [HD] | Prime Video',
#  'The Legend of Red Hand | Short Movie EN',
#  'Spiderman dancing Take on me by A-Ha | DJ IVAN DAVIS',
#  'Jennifer Aniston Drops By to Wish Ellen a Happy Birthday in Person!',
#  "*SPOILER* 2nd Eliminated Queen RuPaul's All Stars 3: Behind the Scenes",
#  "Talkin' Football | JEOPARDY!",
#  'Irreplaceable You | Official Trailer [HD] | Netflix',
#  "'Martin' Cast Reunites, Plays it Coy About TV Reboot | TMZ",
#  "Jamie Dornan Used to Live with 'Desperate' Eddie Redmayne",
#  'Bud Light - The Bud Knight',
#  "Snoke's Throne Room Fight - 16 Bit Scenes",
#  'Sarah Jessica Parker On Kim Cattrall’s Diss | WWHL',
#  'The Dolan Twins & BROCKHAMPTON Today! | TRL Weekdays at 4pm',
#  'How Horse Sounds are Made for Movies',
#  'First Responders Arrive To The Collapsed Floor | Season 1 Ep. 5 | 9-1-1',
#  '#GuacWorld :60 | 2018 Big Game Commercial | Avocados From Mexico',
#  'Rooftop POV Escape from Hong Kong security! 🇭🇰',
#  'A Special Message From This Is Us (Promo)',
#  'ADULTS REACT TO KARMA IS A BITCH CHALLENGE',
#  "Natalie's 2nd Rap - SNL",
#  'will.i.am’s Mother Wouldn’t Let Him Be In Michael Jackson’s Music Video | The Graham Norton Show',
#  'GAME NIGHT - Official Trailer',
#  'Station 19 - Official Trailer',
#  "Rise of the TMNT Official Live Stream Character Art Reveal ft. Andre 'Black Nerd' & Kevin Eastman",
#  'Castle Rock Teaser #2 (Official) • A Hulu Original',
#  'Solo: A Star Wars Story Big Game TV Spot (:45)',
#  "Tide | Super Bowl LII 2018 Commercial | It's a Tide Ad",
#  'Jurassic World: Fallen Kingdom - Official Trailer #2 [HD]',
#  'Marvel Studios’ Avengers: Infinity War - Big Game Spot',
#  'THE CLOVERFIELD PARADOX | WATCH NOW | NETFLIX',
#  'T-Mobile | #LittleOnes | 2018 Big Game Ad',
#  'Fox & Friends Cold Open - SNL',
#  'The blue marble',
#  'Monster - Super Bowl Commercial EXTENDED VERSION',
#  'Puppy Bowl Spot Center: Top 5 Plays',
#  "Brad Makes Chocolate in Ecuador: Part 1 | It's Alive | Bon Appétit",
#  'Rise - Super Bowl Commercial',
#  'Coca-Cola | The Wonder of Us :60',
#  'The Voice 2018 - Super Bowl Commercial',
#  'M&M’S – ‘M&M’S Again’, :15',
#  'Reese Witherspoon Teaches You Southern Slang | Secret Talent Theatre | Vanity Fair',
#  'Budweiser - Original Whazzup? ad',
#  'Pepsi Generations This is the Pepsi | Pepsi | Extended',
#  'Iceberg',
#  'Backstage at the 2018 Puppy Bowl',
#  'Budweiser | Beer Country | :60',
#  'Solo: A Star Wars Story Official Teaser',
#  'Kevin Hart Wildn At Super Bowl After Eagles Win',
#  "Melissa McCarthy's New Dogs Are Pretty, But Not That Smart",
#  'This Is Us - Aftershow: Season 2 Episode 14 (Digital Exclusive - Presented by Chevrolet)',
#  "Cardi B's So Cold in Minneapolis She Can Barely Talk | TMZ",
#  'Can You Recognize These Songs When Played Backwards?',
#  "Normani Kordei of Fifth Harmony Channels Destiny's Child for Bootylicious | Lip Sync Battle",
#  'Amazon 2018 Super Bowl Commercial | Alexa Loses Her Voice (Cardi B, Gordon Ramsey)',
#  'Match the Job to the Person | Lineup | Cut',
#  'Annalynne McCord',
#  'LIFE OF THE PARTY - Official Trailer 1',
#  'Everything Sucks! | Official Trailer [HD] | Netflix',
#  'gays on ice: olympics edition (ft. Adam Rippon)',
#  "Claire Danes And The 'Homeland' Cast Have 'Spy Camp'",
#  "Margot Robbie's Date Tonya Harding Owned the Globes",
#  'Katy Perry Watches Fan Covers On YouTube | Glamour',
#  'Clint Eastwood and Real-Life Heroes from Paris Train Attack',
#  "Angela Rye's Big Decision to Freeze Her Eggs",
#  'Did Solo: A Star Wars Story Trailer Win Over Fans? - Movie Talk',
#  "Jamie Dornan's Wife Still Hasn't Seen Any of the 'Fifty Shades' Films! | Lorraine",
#  'Marvel’s Jessica Jones - Season 2 | Official Trailer [HD] | Netflix',
#  'Lady Doritos',
#  'Fifty Shades of Corden w/ Jamie Dornan',
#  "Miranda Kerr on Having a Baby with Snapchat's Evan Spiegel",
#  'Johnny Weir Slays Celine Dion’s “My Heart Will Go On” | Lip Sync Battle Preview',
#  'Milo Ventimiglia Defends the Crock-Pot',
#  'LOGAN PAUL IS BACK!',
#  'Cut for Time: My Little Step Children (Natalie Portman) - SNL',
#  'Michael Shannon Puts $2.10 in Coins Up His Nose | Secret Talent Theatre | Vanity Fair',
#  'VENOM - Official Teaser Trailer (HD)',
#  'Pizza | Basics with Babish',
#  "John Oliver Warns Meghan Markle What She's Getting Herself Into",
#  'Horton Hears a Who - Nostalgia Critic',
#  'Marvel Studios 10th Anniversary Announcement – Class Photo Video',
#  'Amy Schumer Debuts Her New Film ‘I Feel Pretty’',
#  "This is what happens when you don't sleep in | Will Smith Vlogs",
#  'Meghan Trainor & Guillermo Del Toro: Rat Enthusiasts',
#  'Cecily Strong On The SNL Audition Process | WWHL',
#  'Hang with Timothée Chalamet and Armie Hammer Before the Oscars // Omaze',
#  'This Week I Learned to Slingshot',
#  'Jessica Biel and Chelsea Handler Take a Little Look-See (Full Video)',
#  'The Grand Tour: Season 2, Episode 10 Trailer',
#  "*SPOILER* 3rd Eliminated Queen RuPaul's All Stars 3: Behind the Scenes",
#  "Yara Shahidi Is Turning 18 And Having A 'Voting Party'",
#  'Momsplaining with Kristen Bell #ProductReviews with Ryan Hansen, Ep. 5',
#  'Dan Stevens Can Make Malt Balls Levitate',
#  'The Talk - Nicole Eggert Recounts Abuse Timeline by Scott Baio; Shares Co-Stars New Claims Filed',
#  'Johnny Weir Channels Lady Gaga for Paparazzi | Lip Sync Battle',
#  'Full Actresses Roundtable: Saoirse Ronan, Jennifer Lawrence, Mary J Blige | Close Up With THR',
#  'GOT Creators Making New Star Wars Films, Up Close with the Falcon, and YOUR Solo Teaser Reactions!',
#  'Does Melania Trump Like Cecily Strong’s SNL Impersonation? | WWHL',
#  'Ed Sheeran Tattoo’d Saoirse Ronan’s Handwriting Onto Himself! | The Graham Norton Show',
#  "Liam Neeson's Cupid Audition",
#  'Khloe Kardashian Is Continuing to Workout During Her Pregnancy | Lorraine',
#  'ABSOLUT - The Vodka With Nothing To Hide',
#  'DIY SUPER LONG FRENCH FRY - VERSUS',
#  'I Gave Myself A Kylie Jenner Makeover 💋',
#  'Ernie Designs a Tattoo for His Mom | Kids Draw | Cut',
#  'Hear the Otherworldly Sounds of Skating on Thin Ice | National Geographic',
#  'KUWTK | Scott Disick Admits to Dating 19-Year-Old Sofia Richie | E!',
#  'The FUTURE of FLITE TEST!? -  Help build our WORLD OF FLIGHT',
#  'How Overnight Shipping Works',
#  'Talking about my ghost with the PSYCHIC TWINS',
#  'Atlanta | Season 2: Official Trailer [HD] | FX',
#  '42,000 Match Sphere Gets Lit',
#  'what working tech support is REALLY like',
#  'Black Panther Cast Touches a Chameleon, a Guinea Pig, and Other Weird Stuff | Fear Box | Vanity Fair',
#  'Jimmy Kimmel Interviews Bekah M from The Bachelor',
#  'A Series Of Unfortunate Events - Season 2 | Official Teaser [HD] | Netflix',
#  "See Lala And Kway's Epic And Hilarious Dance-Off | BET Social Awards",
#  'Andy Cohen Weighs In on Kim Cattrall’s Feud with Sarah Jessica Parker',
#  'How Claymation Movies are Made',
#  'Kris Jenner Grills Scott Disick About Dating Sofia Richie -- Watch!',
#  'Catt Sadler Shares Her Side Of E! Exit | The View',
#  "Donald Trump's Valentine's Day Card To Melania Trump",
#  "The Florida Project Should've Been Nominated",
#  'Padma Lakshmi On A #TopChef’s Cancer Diagnosis | WWHL',
#  'Oscar Isaac on Being a New Dad',
#  "Little Girl's Incredible Valentine's Day Rant",
#  'Chloe Kim: Road to PyeongChang',
#  'Young King - Black Panther Jaden Smith Parody (Nerdist Presents)',
#  'Did Beyonce Have To Check An Actress Talking To JAY-Z? | Uncensored',
#  'READY PLAYER ONE - Come With Me',
#  "The Talk - Piers Morgan Goes Off on Omarosa, from 'Celebrity Apprentice' to the White House",
#  'LaVar Ball Performs Hate Me Now by Nas ft. Puff Daddy | Lip Sync Battle Preview',
#  "Michael Blackson Goes After Mo'Nique | BET Social Awards",
#  "Meet America's Oldest Interracial Newlyweds: Edith+Eddie",
#  'Descendants 3 Teaser 💚💜',
#  'Daniel Kaluuya Hugged Oprah at the Golden Globes | The Graham Norton Show',
#  'BEST REACTION EVER! - Mickey and Minnie at Drive-Thru - Valentines Day',
#  'First-Ever Footage of Cobra Kai - The Karate Kid saga continues',
#  "*SPOILER* 4th Eliminated Queen RuPaul's All Stars 3: Behind the Scenes",
#  'Red Gerard on His Gold Medal Snowboard Run',
#  "'Momsplaining with Kristen Bell' #SparkJoy with Marie Kondo, Ep. 6",
#  "Black Panther Cast Answers the Web's Most Searched Questions | WIRED",
#  'looking back',
#  "Can Ellen Get Steph & Ayesha Curry to Reveal Their Baby's Gender?",
#  'Everything You Need to Know About ZOMBIES (Exclusive)',
#  "'Black Panther' Review - The Women Were Clutch",
#  'HOW TO MAKE JOLLIBEE - VERSUS',
#  "Camilla Cabello Performs 'Never Be the Same' | Dancing On Ice 2018",
#  'Weitsprung: Alyn Camara im T-Rex Kostüm | Teil 2 | Beginner gegen Gewinner | ProSieben',
#  'We Lost Him... | Will Smith Vlogs',
#  ...]

# %%
#Helper function to clean data from punctuations
def clean_text(text):
    text = ''.join(e for e in text if e not in string.punctuation).lower()
    return text

# %%
corpus = [clean_text(i) for i in entertainment]
corpus #Cleaned title
# Out:
# ['the trump presidency last week tonight with john oliver hbo',
#  'nickelback lyrics real or fake',
#  'i dare you going bald',
#  'roy moore  jeff sessions cold open  snl',
#  'spoilers shiva saves the day talked about scene ep 804  the walking dead',
#  'spaghetti burrito vs spaghetti burrito',
#  'amazon christmas advert 2017  toys  games',
#  'whats inside a detectives car',
#  'people are awesome  the pet collective present pets are awesome',
#  'elders react to iphone x facial recognition animojis',
#  'will it watermarble sister edition  watermarbling 9 random objects in nail polish',
#  'jason momoa wows hugh grant with some dothraki  the graham norton show',
#  'daddys home 2  movie review',
#  'veteransday thank you for everything',
#  'batman gotham by gaslight  exclusive trailer 2018',
#  'watch norman reedus come face to face with his ‘walking dead’ double',
#  'reacting to running a half marathon  meganbytes ep 101',
#  'justice league reactions should disney buy netflix  the john campea show',
#  'rosie o’donnell on donald trump’s hostility toward her  wwhl',
#  'jason momoa  lisa bonet love at first sight',
#  'fantasy feat amber liu by superfruit',
#  'taylor swift  “new year’s day” fan performance',
#  'hm holiday 2017 starring nicki minaj – official teaser',
#  'owen wilson on meeting julia roberts and tandem biking',
#  'meryl streep meets anna wintour at vogue',
#  'i trained to become batman 🦇 justice league',
#  'sean astin knew nothing about lord of the rings once upon a time',
#  'president bill clinton on dictators democracy  why we need immigrants more than ever',
#  'a day in the life of david letterman',
#  'live in the now',
#  'dark  official trailer hd  netflix',
#  'where is tokyos greatest view',
#  'dropping and catching a paper airplane at 2000 feet',
#  'i miss the old taylor',
#  'keith urban  female official audio',
#  'harry styles canta sign of the times a x factor italia  live show 3',
#  'kuwtk  scott gets upset over being uninvited to khloe ks party  e',
#  'ot genasis talks about his come up opens up about his sons autism   more',
#  'tamar braxton talks divorce in first interview',
#  'fire breathing full twist backflips in one minute  guinness world records day',
#  'beauty guru gets a makeover finale',
#  'brian justin crum  wild side',
#  'katy perry  swish swish behind the scenes with just dance',
#  'selena gomez singing wolves and it aint me full instagram live  acoustic',
#  'how to do thanksgiving makeup that has nothing to do with the 566 federally recognized tribes',
#  'slow mo katana sword  4k  the slow mo guys',
#  'jason momoa shows off his aquaman quindent  the graham norton show',
#  'american crime story season 2 the assassination of gianni versace trailer hd',
#  '10 life hacks you need to know with teens react',
#  'disney sent mickey mouse to my house',
#  'does gwen stefani know if blake shelton is peoples sexiest man alive  access hollywood',
#  'funfetti is extremely fun',
#  'lindsey and\u200b mark’s  iconic dance  dancing with the stars',
#  'colin farrell dishes on rendezvous with girlfriend',
#  'taylor swift instagram story  target 111417',
#  '100 people hold their breath for as long as they can',
#  'victoria beckham gives strangers fashion advice for 2 in central park  vanity fair',
#  'model fei fei sun perform skincare magic  beauty secrets  vogue',
#  'justice league  “come together”  todrick hall jfla mario bautista samantha harvey clara marz',
#  'jaden smith watch me',
#  'all of jims best pranks   the office us',
#  'lord of the rings tv series gets multiseason order at amazon  news flash  entertainment weekly',
#  '5 strange things that happened to stranger things’ joe keery on his gq photo shoot',
#  'pnk carpool karaoke',
#  'justice league  movie review',
#  'kim kardashian lets gender of third child slip',
#  'larry david outtakes – mean tweets about jimmy kimmel',
#  'demi lovato  luis fonsi  echame la culpa teaser',
#  'how to be an aquarius',
#  'kuwtk  kris jenner brings her personal scribe to lunch  e',
#  'kim kardashian explains her familys rumor control rule',
#  'justice league  movie review is it what weve been waiting for',
#  'menace the pile of matchboxes which can learn',
#  'remy ma is on top of the world',
#  'inside danica roems historic victory',
#  'jordan\u200b and\u200b \u200blindsay’s  iconic dance  dancing with the stars',
#  'lord of the rings tv series lands at amazon  will explore new stories',
#  'rampage  official trailer 1 hd',
#  'spill your guts or fill your guts w kim kardashian',
#  'miranda sings hijacks a strangers tinder  vanity fair',
#  '73 questions with liza koshy  vogue',
#  'jordan peele crashed a get out college course',
#  'the talk  eve reacts to nicki minajs racy magazine cover i just dont think its right',
#  'blake shelton is milking his title of sexiest man alive',
#  'holo cappuccino  diy diamond cappuccino test maybe dont drink this',
#  'justice league  movie review',
#  'should hillary clinton be impeached',
#  'who matt reeves wants as batman is basmati blues culturally insensitive the john campe show',
#  'deadpool 2 teaser released  movie talk',
#  'runners by danakadan official music video  wong fu presents',
#  'behind the curtain  official trailer',
#  'f the prom 2017  official trailer hd',
#  'the bipartisan pastime of harassing women',
#  'linmanuel miranda and macey hensley face off in historical trivia',
#  'kim kardashians surrogate didnt know whose baby she was carrying',
#  'macklemore’s naked justin bieber painting  wwhl',
#  'tracee ellis ross on cher michael jackson  diana ross',
#  'todrick returns to broadway',
#  'a christmas prince  official trailer hd  netflix',
#  'keep me coming by superfruit',
#  'kuwtk  a very kardashian holiday sneak peek  e',
#  'motor sport  cardi b x migos x nicki minaj dance  matt steffanina cover',
#  'staronfox exclusive clip for theybfcom',
#  'religion of sports season 2  trailer 1',
#  'chancegiving monologue  snl',
#  'dont hurt me',
#  'transforming summer mckeen into me',
#  'will ferrell left speechless as mark wahlberg reveals he has a third nipple  good morning britain',
#  'diana ross lost her fanny pack',
#  'hd julia roberts interview on today show 11162017',
#  'ball surprise prank woody and kleiny',
#  'rip arya',
#  'weekend update on senator al franken  snl',
#  'gordon is served “the weirdest pizza i’ve ever seen”  kitchen nightmares',
#  'funny japanese game show slippery stairs  just hilarious',
#  'jon stewart hosts night of too many stars',
#  'drug store nail powders fail what the sally hansen',
#  'justice league spoiler review and discussion',
#  'mali music and jennifer hudson are recording a song',
#  'cooking a turkey on a car engine',
#  'making the grand tour mark webbers driver audition',
#  'highlights from the 2017 american music awards',
#  'come back barack  snl',
#  'holding a baby for the first time in slow motion  first takes',
#  'marvels agents of shield season 5 trailer hd',
#  '2017 american music awards all the showstopping performances',
#  'justice league a box office disaster  box office report',
#  'mcdonalds will no longer serve this fan favorite drink',
#  'diy clear pumpkin pie',
#  'grownish  grownish x bfast club  freeform',
#  'stranger things cast answer the webs most searched questions  wired',
#  'binging with babish rachels trifle from friends',
#  'sofia vergara wants to see ellen in her underwear',
#  'the voice 2017  pitch perfect 3 x the voice freedom ’90 x cups” digital exclusive',
#  'liza koshy touches a bearded dragon chinchilla  other weird stuff in the fear box  vanity fair',
#  'thanksgiving slay makeup tutorial',
#  'victoria’s secret model sara sampaio’s easy bombshell makeup look  beauty secrets  vogue',
#  'lindsey and\u200b mark’s  freestyle  dancing with the stars',
#  'volunteering with youtubers',
#  'how to do a beauty vlog for tarte cosmetics',
#  'kate bosworth  shemar moore disagree on peoples sexiest man',
#  'african grey parrot swearing in an irish accent',
#  'terry crews says he was sexually assaulted',
#  'the poop in my pants  rick and morty  adult swim',
#  'the internet is under attack net neutrality is dying and what you can do',
#  'the happiest day of my life',
#  'jet packinski touches a hairless rat rooster  other weird stuff in the fear box  vanity fair',
#  'chicken girls  annie  hayden in “broken”  ep 8',
#  'how to design a comic book page',
#  'ellen surprises the audience with channing tatum during 12 days',
#  'what went wrong with justice league at the box office',
#  'camila mendes has twitter problems',
#  'daveed diggs doesnt always cry at movies just his own',
#  'sneaking in everywhere for free yellow vest experiment',
#  'the crown  season 2  trailer philip hd  netflix',
#  'jordan\u200b and\u200b \u200blindsay’s  repeat  dancing with the stars',
#  '12 strong  official trailer 2',
#  'zendayas wavycurly hair tutorial',
#  'justice league could lose wb big money  sju',
#  'saoirse ronan on harassment need to know theres support here no matter what  close up with thr',
#  'are critics what killed justice league sony pay too much for tarantino  the john campea show',
#  'christina aguileras whitney houston tribute at amas is breathtaking  amas 2017  access hollywood',
#  'ford thunderbird sc commercial 1989',
#  '2017 american music awards red carpet fashion  e news',
#  'kuwtk  kris jenner  jonathan cheban put on disguises  e',
#  'jackson pollock in 60 seconds',
#  'masters of the sun the zombie chronicles augmented reality experience release date trailer',
#  'verizon 360 live the macy’s thanksgiving day parade',
#  'krysten ritter has weak tinder game',
#  'smallfoot  teaser trailer',
#  'black mirror  arkangel  official trailer hd  netflix',
#  'fail compilation  massive chain reaction goes up the stairs ft berlagawesome',
#  'glowing speaker iphone mod see your music in rgb',
#  'pitch perfect 3 x the voice freedom ’90 x cups',
#  'sarah michelle gellar vs sarah michelle prinze',
#  'pitch perfect 3  riffoff clip hd',
#  'marvel’s agents of shield  season 5 premiere special preview',
#  '2017 miss universe national costume show',
#  'my dad paints my nails he doesnt know what youtube is',
#  'making the grand tour jamess candidate for the driver',
#  'sesame street sharing things stranger things parody',
#  'meghan markle engaged to prince harry  the view',
#  'ray j and princess love’s big news',
#  'black mirror  crocodile  official trailer hd  netflix',
#  'ellen makes friends with bts',
#  'ed sheeran delivers a perfect performance  live shows  the x factor 2017',
#  'miss universe crowd shouts boo not happy with ms jamaica just 2nd runner up',
#  'rhoa kim zolciakbiermann says kenya moores husband doesnt exist season 10 episode 4  bravo',
#  'teens read 10 funny friend zone texts react',
#  'the voice 2017  team miley man i feel like a woman',
#  'howto make a steak sandwich with matty matheson',
#  'jennifer lawrence i become incredibly rude to avoid fan encounters in public',
#  '90s toy mystery box ft joe sugg',
#  'bts fans get the surprise of a lifetime',
#  'daisy ridley talks about spending time with carrie fisher on the set of the force awakens',
#  'john mayer on andy cohen’s annoying habit  wwhl',
#  'coming out elle mills style',
#  '73 questions with michael b jordan  vogue',
#  'this week i learned to saber a champagne bottle',
#  'reacting to bts mic drop mv',
#  '2018 grammy nominations announced  kendrick lamar jayz bruno  more',
#  'kris jenner would love to live with kim kardashian  kanye west again',
#  'paddington 2  full us trailer',
#  'a magical holiday',
#  'a sainty switch',
#  'marvel studios avengers infinity war official trailer',
#  'all the money in the world  official trailer hd',
#  'all the money in the world  tv spot featuring christopher plummer',
#  'kylie jenner pregnancy reveal on keeping up with the kardashians',
#  'adriana lima’s victoria’s secret sleepover  vogue',
#  'joe keery swings by to talk about stranger things 2',
#  'armie hammer and timothée chalamet talk passionate first rehearsal',
#  'honest trailer commentaries  the room',
#  'john mayer and nicki minaj’s twitter flirting  wwhl',
#  'avengers 4 who will die  movie talk',
#  'riverdale season 2 josie takes center stage in the upcoming 3 part episode  sweetwater secrets',
#  'los angeles’s dangerous obsession with car chases  the new yorker',
#  'shes gotta have it  my name isnt  netflix',
#  'verizon commercial 2017  usa',
#  'kelly clarkson carpool karaoke',
#  'justin timberlake and stephen harmonize the national anthem',
#  'james franco brings tommy wiseau to kimmel',
#  '10 crazy ebay items',
#  'avengers infinity war  trailer review',
#  'chelsea handler questions whether shes cut out for a relationship',
#  'disneys live action mulan  liu yifei aka crystal liu cast  reaction',
#  'i pretended to be a model on a shoot for jigsaw',
#  'magic magnetic nail polish  maybe dont wear metal',
#  'black mirror  black museum  official trailer hd  netflix',
#  'i became my sim for a day challenge',
#  'thoroughbreds  official trailer hd  in theaters march 9 2018',
#  'kuwtk  kendall jenner  khloe kardashian consider getting a gun  e',
#  'twitter is furious vs fashion show aired models runway fall unedited',
#  'at home with amy sedaris  amys notso holiday special  trutv',
#  'melania trump is dreaming of a dark christmas',
#  'jimmy kimmel on twitter war with roy moore',
#  'youtubers react to their old youtube channel profile 2',
#  '2017 mama in hong kong btsintro perf  not today',
#  'black mirror  hang the dj  official trailer hd  netflix',
#  'ed sheeran on his girlfriend and working with beyoncé',
#  'flinch w bts',
#  'midnight sun  official trailer  in theaters march 23',
#  'drop the mic michael bennett vs vanessa hudgens  full battle  tbs',
#  'crisis on earthx  snart  the ray kiss',
#  '1000000 dominoes falling is oddly satisfying',
#  'white house christmas cold open  snl',
#  'the cast of star wars the last jedi has mixed feelings on porgs',
#  'jordan peele breaks down get out fan theories from reddit  vanity fair',
#  'youtube creators for change natalie tran  white male asian female',
#  'star wars the last jedi  training featurette',
#  'the tokyo stomp feat anna akana',
#  'ashanti speaks on irv gotti and murder inc  everyday struggle',
#  'little mix bring the power  cnco to the x factor final  final  the x factor 2017',
#  'black mirror  metalhead  official trailer hd  netflix',
#  'diy pizza pouch  wearable pizza',
#  'the cast of star wars the last jedi talk kylo ren jedi controversy harrison ford  secrets',
#  'top 10 strangest things that happen to your body in space',
#  'queen biopic stops production avengers fighting alien cannon fodder again  the john campea show',
#  'prince harry and meghan markle get the alison hammond experience  this morning',
#  'star wars in public',
#  'joe rogan and eddie bravo on bob sapp vs nogueira part 1 of 2',
#  'jurassic world fallen kingdom  trailer thursday run hd',
#  'ashanti talks murda inc relationships new music  more',
#  'thomas train stunts',
#  'will it christmas tree',
#  'learn to break a glass with your voice  learn quick',
#  'welcome to hell  snl',
#  'alessandra ambrosio’s wax sculpture',
#  'xscapes tamika scott falls during epic wardrobe malfunction onstage  tmz',
#  'tiffany haddish details her dinners with barbra streisand  taylor swift',
#  'justice league will fail to hit 700 million at box office  box office report',
#  'testing nail products from wish nails remove toes hollow nail polish peeloff nails wish buy now',
#  'billy bush believes the women accusing trump of sexual assault',
#  'black mirror  uss callister  official trailer hd  netflix',
#  'chris pratt  bryce dallas howards kids are bffs',
#  'the voice 2017 keisha renee  top 10 all by myself',
#  'actors on actors saoirse ronan and kristen wiig full video',
#  'the talk  hilary duff dishes on boyfriend matthew koma third times a charm',
#  'morgan freeman hosts the breakthrough prize  nat geo live',
#  '2017 mama in hong kong btsbts cypher 4  mic dropsteve aoki remix ver',
#  'vanderpump rules lisa confronts sandoval for talking crap season 6 episode 1  bravo',
#  'youtube rewind the shape of 2017  youtuberewind',
#  'black mirror  season 4  official trailer hd  netflix',
#  'saoirse ronan knows why you love lady bird',
#  'is sam smith team kim kardashian or team taylor swift  plead the fifth  wwhl',
#  'grinch holiday humming challenge ft grace helbig',
#  '‘the grand tour’ café',
#  'what would a quentin tarantino star trek movie look like  sju',
#  'quentin tarantino developing new star trek movie  movie talk',
#  'glam masters  official trailer  new series premieres february 28 at 109c  lifetime',
#  'outback bowl is january 1st',
#  'star wars the last jedi cast on carrie fishers final performance  e live from the red carpet',
#  'saoirse ronan says firsttime movie director greta gerwig was born to do lady bird',
#  'snl invisible box challenge',
#  'kristen wiig struggles with hallelujah',
#  'ramsay shuts down restaurant after finding raw chicken next to cooked chicken  kitchen nightmares',
#  'its day 12 of ellens 12 days of giveaways allison janney gets dramatic with ellen',
#  'neil patrick harris guest host monologue on jimmy kimmel live',
#  'wags atlanta first look  e',
#  'i snuck into youtube rewind 2017 i was invited  behind the scenes  nyc',
#  'after show patti labelle’s advice for mariah carey  wwhl',
#  'holiday makeup look',
#  'riverdale  mad world  the cw',
#  'global ban on glitter this is not a drill the best day of my life',
#  'tank has words of support for tyrese',
#  'why avengers infinity war will succeed where justice league failed  the john campea show',
#  'grownish freeform college parties trailer hd  blackish spinoff',
#  'best carol burnett show bloopers',
#  'the real reason tyrese married his ex wife',
#  'at home with amy sedaris  astronaut relationship jokes ft justin theroux  trutv',
#  'jurassic world fallen kingdom  official trailer hd',
#  'dude vs wild  nevada mountains',
#  'take a break the forum general manager',
#  'guest host melissa mccarthy interviews dave franco',
#  'gwen stefani talks moving in with blake shelton',
#  'sarah paulson has twitchy eye from 2017',
#  'madonna and anderson cooper play sketching with the stars with kelly  ryan',
#  'claire foy and matt smith’s netflix and chill picks  wwhl',
#  'mechanical lego keyboard',
#  'the flash  deleted scene  the cw',
#  'david dobrik crashes liza and gabbies qa',
#  'youtubers react to youtube rewind 2017',
#  'marvels jessica jones  date announcement shes back hd  netflix',
#  'lost star wars footage of luke skywalker at the cantina',
#  'james franco audience questions monologue  snl',
#  'rebel wilsons does her pitch perfect audition  the graham norton show 2017  bbc one',
#  'singing my makeup routine christmas edition',
#  'how to take out atats  easy method explained',
#  'mamrie hart gets under the sheets on collider ladies night',
#  'danny masterson fired from netflix series the ranch amid rape allegations  access hollywood',
#  'ready player one  official trailer 1 hd',
#  'visit with santa cold open  snl',
#  'bleach blonde baby teaser',
#  'live from the red carpet of star wars the last jedi',
#  'mixing all my nail powders together for sale if u keep it on the dl',
#  'james franco reads bad video game lines as tommy wiseau  up at noon live',
#  'attempting every 2017 trend',
#  'could kevin feige save dc does alita battle angel look great or terrible the john campea show',
#  'tiffany haddish thanks her bullies for making her rich forces george stephanopoulos to dance',
#  'cardistry  virtuoso  rise feat the fw17 virtuoso deck',
#  'new yorkers share their story for a dollar  part 5',
#  'the evolution of the movie trailer',
#  '3d printed monster spitfire  flite test',
#  'the quest for the holy grail meets parkour in real life in hdr 8k',
#  'scott disick goes sneaker shopping with complex',
#  'logan paul  santa diss track official music video',
#  'the last jedi cast answers the webs most searched questions  wired',
#  'spoilers midseason finale talked about scene  the walking dead',
#  'fuller house  season 3b  official trailer hd  netflix',
#  'does tiffany haddish think nene leakes is funny  rhoa  wwhl',
#  'zendaya talks about zac efrons reaction to their onscreen kiss',
#  'jennifer hudson is christmas biggest fan',
#  'spiderman into the spiderverse  official teaser trailer',
#  'rest in peace angry grandpa',
#  'star wars the last jedi first reactions and world premiere report  the john campea show',
#  'we tried the 2017 victorias secret model diet for a week',
#  'best videos of the year 2017  people are awesome',
#  'john boyega finn interview  star wars the last jedi red carpet world premiere',
#  '7 days in entebbe  official trailer hd  in theaters march 2018',
#  'my gender',
#  'how to hijack amazon prime now for good',
#  'star wars cast takes which star wars character are you quiz',
#  'dwayne johnson has exciting baby news',
#  'matt damon explains why good will hunting has so much cursing',
#  'star wars the last jedi  movie review',
#  'howto make chocolate mousse with matty matheson',
#  'jennifer hudson “burden down”  the voice 2017',
#  'santa claus is comin to town carpool karaoke',
#  'kids interview the star wars the last jedi cast with daisy ridley mark hamill  more  peopletv',
#  'youtuber holiday gift wrapping ft eva gutowski  kyle krieger',
#  'the bachelor returns januarie 1',
#  'comedian tig notaro says its a huge relief louis ck was removed from comedy industry  the view',
#  'keaton jones why do they bully powerful message',
#  'star wars lukes journey to the last jedi',
#  'sporcle world record  typing every country in under 3 minutes',
#  'lavar ball  sons on family business discipline donald trump  more',
#  'tom hanks and stephen argue christmas tree technique',
#  'anna camp takes the bra off her back for anna kendrick',
#  'the last jedi cast touches bearded dragons  other weird stuff  fear box  vanity fair',
#  'bleach blonde baby official video',
#  'harry styles to the rescue',
#  'the last jedi cast competes in a compliment battle  teen vogue',
#  'two selena gomezes meet for the first time fbe',
#  'tmobile ceo john legere  were bringing the uncarrier to tv',
#  'the 1517 to paris  official trailer hd',
#  'christmas inheritance  official trailer hd  netflix',
#  'star wars the last jedi review spoiler free',
#  'wonder woman director patty jenkins on picking the right project  close up with thr',
#  'stranger things actor reveals major hint about season 3',
#  'black panther new international trailer released  movie talk',
#  'star wars the last jedi review',
#  'interview with clarice lispector  são paulo 1977 english subtitles',
#  'youtubers react to invisible box challenge',
#  'kevin hart lives his truth and opens up about being irresponsible and more',
#  'will smith watched his sons jump out of an airplane',
#  'we demand 1 fries on the new mcdonalds dollar menu',
#  'the late show rescue dog rescue with nick jonas',
#  'ayrton little was accepted into harvard university at 16 years old',
#  'star wars the last jedi cast play would you rather  mtv movies',
#  'i made him fabulous  best friend makeover challenge with boyinaband',
#  'mixing all my tea together warning some tea was spilled',
#  'tamars executive decision  tamar  vince  we tv',
#  'i have a condition that makes me feel like im dreaming all the time',
#  'netflix is trolling its viewers and we love it  sju',
#  'the last jedi cast answers your questions behind the scenes of the red carpet live stream  more',
#  'the worlds hardest scooter trick',
#  'disney officially to buy 21st century fox for 524 billion  ign news',
#  '17 of 2017 the year in pop culture ft damon and jo  kingsley',
#  'riverdale s2e09 silent night deadly night preshow  sweetwater secrets',
#  'matt damon and the hemsworth brothers run into ryan',
#  'jaguar vs caiman  big cat week',
#  'crosswalk the musical on broadway w hugh jackman zendaya  zac efron',
#  'adam driver and stephen act out a star wars scene using dolls',
#  'recreating our favorite vines',
#  'will smith asks strangers for money',
#  '4 ton wrecking ball in slow motion  the slow mo guys',
#  'john cena answers the webs most searched questions  wired',
#  'the polka king  official trailer hd  netflix',
#  'giving my 13 year old niece the emo phase',
#  'i trained like rey from star wars for a month ⚔️',
#  'riverdale  chapter twentythree the blackboard jungle trailer  the cw',
#  '“santa baby” ft ciara  taraji’s white hot holidays',
#  'woody woodpecker trailer 1 new 2018 live action comedy movie hd',
#  'how noah galvin makes evan hansen his own',
#  'clarice probes hannibal lecter about trumps russia ties',
#  'my skincare routine',
#  'chris brown  cardi b  lil kim  remy ma  yo gotti live hot 97 hot for the holidays concert 2017',
#  'star wars the last jedi will have a massive opening weekend  sju',
#  'star wars the last jedi  which audience score should we believe',
#  'do you want to hear a woke eminem  everyday struggle',
#  'white house tree trimming cold open  snl',
#  'pancake art challenge 4 learn how to make mario odyssey star wars jedi nintendo food diy pancake',
#  'gucci gang country edition dear ryan',
#  'youtubers react to top 10 vevo channels of all time',
#  'jack black  this week on gmm',
#  'introducing communist amazon echo',
#  'is andy cohen or anderson cooper more kinky in bed  wwhl',
#  'youll shoot your eye out performance  a christmas story live',
#  'diy snowglobe nails i built a snowman on my nail',
#  'trying on engagement rings no proposal',
#  'mark hamill didn’t tell carrie fisher the big star wars secret  the graham norton show',
#  'what happens if you fill up a car with cocacola',
#  'attempting holiday life hacks',
#  'star wars the last jedi scores an a cinemascore and 2nd largest opening ever  the john campea show',
#  'john boyega and oscar isaac read hilarious thirst tweets',
#  'the voice 2017 chloe kohanski  finale “wish i didnt love you”',
#  'mortal engines official teaser trailer hd',
#  'oceans 8  trailer teaser',
#  'the shape of water  movie review',
#  'keeping up with the kardashians katchup s14 ep11  e',
#  'star wars the last jedi  movie review black nerd',
#  'star wars the last jedi spoiler review and discussion part 1',
#  '24 strings bass solo again',
#  'small details you missed in the last jedi',
#  'testing kylie 360 brush set vs morphe dupes',
#  'oceans 8  official 1st trailer',
#  'its true wife and i are getting a divorce  heres whats next for us',
#  'christmas booty song',
#  'the voice 2017 chloe kohanski and billy idol  finale white wedding',
#  'sicario 2 soldado  official teaser trailer hd',
#  'step up high water  official trailer',
#  'narcos  season 4  teaser hd i netflix',
#  'sesame street puppeteers explain how they control their puppets  wired',
#  'thank you peter capaldi  doctor who christmas  christmas night  98c on bbc america',
#  'forging a damascus anvil part 2',
#  'simply nailogicals holoday hits 2017',
#  'star wars the last jedi has second largest opening ever amidst mixed fan reactions  movie talk',
#  'weekend update on doug jones defeating roy moore  snl',
#  'is the last jedi the most divisive star wars movie ever spoilers  sju',
#  'why imperial admirals had high suicide rates canon  star wars explained',
#  'the voice 2017  the season 13 voice champion is',
#  'bedtime with babish a new podcast',
#  'star wars the last jedi  becoming rose',
#  'grace and frankie  season 4  official trailer hd  netflix',
#  'music is magic',
#  'star wars episode ix story pitched by jj abrams  movie talk',
#  'why the holidays ruin friendships',
#  'ralphie to the rescue performance  a christmas story live',
#  'the great festive bake off does stay another day  the great british bake off',
#  'still to come this season on keeping up with the kardashians  e',
#  'james franco reads mindblowing philosophy quotes as tommy wiseau  vanity fair',
#  'christian bale rosamund pike  wes studi speak on hostiles',
#  'mamma mia here we go again  trailer',
#  'cut for time hallmark channel christmas promo james franco  snl',
#  '73 questions with gina rodriguez  vogue',
#  'diy giant swiss roll  versus',
#  'impossible rubiks cubes',
#  'foot locker x jordan  “boldlikekawhi” feat kawhi leonard',
#  'khloe kardashian confirms pregnancy  reveals baby bump  hollywoodlife',
#  'im not a child im 20  living differently',
#  'will smith  joel edgerton answer the webs most searched questions  wired',
#  'seven seconds i teaser hd i netflix',
#  'kpop stars carry jonghyun’s coffin after suicide',
#  'count on christmas performance ft bebe rexha  a christmas story live',
#  'youtubers react to top 10 youtube videos of 2017',
#  'full face of youtuber christmas presents',
#  'clarabelle flirted with me  disneyland impressions',
#  'the rock’s make a wish surprise',
#  'kate winslet commits to her ugly christmas sweater look',
#  'becoming plum with sarah lamb',
#  'christian bale division is not the way to go',
#  'college kids react to kpop bts monsta x seventeen twice red velvet',
#  'merry christmas in dominoes 🎅🏻 christmas card',
#  'how fleetwood mac makes a song',
#  'full stream  real madrid  fc barcelona warmup elclásico',
#  'margot robbie how hollywoods horrible situation brings actresses together  close up with thr',
#  'real madrid players warm up before the clásico',
#  'hugh jackman on keeping his 21year marriage strong the crazy ups  crazy downs  peopletv',
#  'the path season 3 trailer official • the path on hulu',
#  'part 1  gwen stefani with blake shelton  instagram  december 24 2017  christmas eve with family',
#  'the 75th annual golden globes  there’s a lot to talk about promo',
#  'jonathan groffs festive christmas sweater',
#  'koala brawl  koalas fight on australian road  near adelaide',
#  'the twelfth doctor regenerates peter capaldi to jodie whittaker  doctor who christmas special 2017',
#  'home for the holidays',
#  'spoilers the twelfth doctor regenerates – peter capaldi to jodie whittaker  doctor who  bbc',
#  'paddington 2   us trailer 2',
#  'lying on a 150k bed made of horse hair',
#  'top 10 worst movies 2017',
#  'drop the mic pentatonix vs bell biv devoe  full battle  tbs',
#  'the assassination of gianni versace american crime story  season 2 first look  fx',
#  'wizards of waverly place the movie  disneycember',
#  'binging with babish the wire special',
#  'hot wheels in the garden',
#  'lauren london goes sneaker shopping with complex',
#  'the open house  official trailer hd  netflix',
#  'diy rugrats reptar bar  featuring reptiles',
#  'charlamagne tha god  joe budden present this year was dopetrash 2017 full episode',
#  'alien covenant sequel cancelled mark hamills opinion of the last jedi  the john campea show',
#  'michelle williams recalls being mistaken for the destinys child singer at a concert exclusive',
#  'i threw my crush her own prom',
#  'zac efron made michael jackson cry  the graham norton show',
#  '2017 kbs가요대축제 music festival  방탄소년단  dna dna  bts 20171229',
#  'the royals new season first look  e',
#  'star wars  war pigs',
#  'best of hevesh5 8',
#  'blank canvas 2017 year in review',
#  'animal electricity  fingerling fart monkey teardown',
#  '1982 toyota corolla ad',
#  'ryan seacrest dishes on new years eve american idol',
#  'the end of the fking world  official trailer hd  netflix',
#  'karl pilkington predicts black mirror spoilers',
#  'luke skywalker vs kylo ren 16 bit',
#  'fifty shades freed  mrs grey will see you now hd',
#  'so sorry',
#  'ellen cooks up a huge surprise for food critic kalen allen',
#  'i gave myself a kim kardashian hair makeover 💇',
#  'shaving my mustache',
#  'paris hilton engaged to chris zylka',
#  'whats in my peely bag recreating 5 of my nail peelies  2017 yearinreview',
#  'the 77 year old ballet dancer sharing seven decades of experience  amazing humans',
#  'its not easy to be a tram driver',
#  'danielle bregoli rejects logan pauls apologies over suicidehanging video  tmz',
#  'slender man  official trailer hd',
#  'anderson cooper walked out of the new star wars movie',
#  'blumhouses truth or dare  official trailer hd',
#  'the four cast plays never have i ever',
#  'bright  leaked orc auditions confirm sequel rumors  netflix',
#  'jodie foster says big budget films ruin viewing habits  movie talk',
#  'bts special  방탄소년단 스페셜 2017 kbs song festival  2017 kbs 가요대축제  20171229',
#  'everything ellen knows about deepstate and eric trump',
#  'america ferreras busy 2018 pregnancy and the times up movement',
#  'volatile owner tears into customer over microwaved lamb  kitchen nightmares',
#  'jessica chastains italian inlaws might hate her',
#  'one thing arnold schwarzenegger told me that i’ll never forget  will smith vlogs',
#  'disney resort tour  yacht  beach club resort hotel grounds tour pool locations  more',
#  'laura govan addresses rumors of pregnancy  affair with vincent herbert hes so not my type',
#  'tamar braxton exs alleged new fling laura govan speaks out  daily pop  e news',
#  'my big problem with the iphone x',
#  'tesla model 3 first drive and impressions  neat stuff in cool cars',
#  'my next guest needs no introduction with david letterman  trailer hd  netflix',
#  'khloé kardashian reveals pregnancy  delivery details',
#  'winchester  official trailer  hd helen mirren jason clarke',
#  'best of 2017  black nerd rants',
#  'espns katie nolan extended cut',
#  'box office winners and losers of 2017  movie talk',
#  'full stream open doors training session',
#  'michael jacksons dont stop till you get enough  by jay',
#  'inventing the wheel',
#  'dazed  confused  livin speech',
#  'disneyparkslive fantasy in the sky new years eve fireworks  disney world',
#  'our lit new years eve',
#  'nerf puttputt golf challenge',
#  'juju smithschuster pranks steelers fans  undercover news interview',
#  'meet the new sugar pine 7',
#  'billions season 3 2018  official trailer  damian lewis  paul giamatti showtime series',
#  'daz watches worst kickstarters 9',
#  'whole ocean is frozen insane',
#  'oprah winfrey receives cecil b de mille award at the 2018 golden globes',
#  'gateway to sedona debunk',
#  'golden globes 2018 what to expect as celebs hit the red carpet in all black',
#  'the mystery that keeps neil degrasse tyson up at night',
#  'reacting to my first video try not to cringe compilation',
#  'iphone x vs 100 tide pods experiment  will it survive',
#  'checking out the new mcdonald’s dollar menu',
#  '2018 golden globes who should win who will win  thr',
#  '10 best moments from 2018 golden globes',
#  'will it meatloaf taste test',
#  'matty matheson reviews the internets most popular food videos  bon appétit',
#  'oprah winfrey  2018 golden globes  full backstage speech',
#  'golden globes 2018 the most memorable moments  thr news',
#  'marvel studios black panther  rise tv spot',
#  'emma watson attends golden globes with imkaan activist  e live from the red carpet',
#  'kuwtk  katch the two night kardashian event this sunday and monday  e',
#  '1 million subscriber watch party',
#  'logan paul dont be that guy in japan or anywhere else',
#  'matthieu ricard leads a meditation on altruistic love and compassion  talks at google',
#  'golden globes movie predictions  collider scoreboard',
#  'cantina theme played by a pencil and a girl with too much time on her hands',
#  'tully  official teaser trailer  in theaters april 20',
#  'altered carbon  official trailer hd  netflix',
#  'sarah jessica parker finally gets asked to prom',
#  'kids try 100 years of the most expensive foods  bon appétit',
#  'tonya harding cuts interview short  the view',
#  'chris hemsworth reveals where he keeps his hammer',
#  'dame helen mirren finds out shes only 72 years old',
#  'diy study hacks how to be productive after school  study tips to get better grades',
#  'clip why president obama stays in the pocket with his dad moves hd  netflix',
#  'kuwtk  khloé kardashian sees the positive in rob  chynas drama  e',
#  'lena waithe is winning',
#  'camila cabello loves ikeass meatballs  elvis duran inteview highlight',
#  'flower 2018  official us trailer hd',
#  'venom  tom hardy full brazil comic con panel  ign first',
#  'charlamagne defends ginuwine after being labeled transphobic by twitter stampede',
#  'when your catfish is actually a fish w sally hawkins',
#  'match the dog to their owner  lineup',
#  'marbles magnets and music synchronized',
#  'westworld  season  1 review',
#  'riverdales casey cott reviews riverdale memes  teen vogue',
#  'organize  garage clean out and where to take stuff',
#  'gerard butler le declara su amor a ana patricia en vivo',
#  'trust  season 1 official trailer hd  fx',
#  'trying the fruitarian raw vegan diet for a week 🍎🍌🍍',
#  'whats in jeanine amapolas bag  spill it  refinery29',
#  'keri hilson has emotional meeting with psychic medium reginald lewis',
#  'rebel wilson heart rate monitor feat hugh jackman',
#  'rich brian goes sneaker shopping with complex',
#  'cruise ship caught in a bomb cyclone norwegian breakaway',
#  'blockers  official trailer hd',
#  'the weeknd blasts hm over racist monkey ad featuring black child ends partnership',
#  'things not to say to single parents',
#  'jennifer lopez and alex rodriguez bring hope and relief to stormravaged puerto rico',
#  'our cartoon president 2018  official trailer  stephen colbert showtime series',
#  'robot writes new harry potter chapter',
#  'worlds smallest cat  big cats preview  bbc one',
#  'geazy on stepping away from hm being a crazy gemini halsey  more',
#  'marvel studios black panther  warriors of wakanda',
#  'helen mirren donald sutherland talk oscars honor timesup movement golden globes  more',
#  'ellen pays tribute to her late father',
#  'sam rockwell not halsey won a golden globe  snl',
#  'how i became a makeup artist with pictures',
#  'camila cabello performs  never be the same  gma live',
#  'we found the real maui',
#  'kyrie irving on conspiracy theories tightening his handle and going to the celtics ep 4',
#  'things that are lower',
#  'pandas  official teaser hd',
#  'log cabin timelapse built by one man in the forest real life minecraft',
#  'why ikea wants you to pee on this ad',
#  'alex inc  official trailer',
#  '300000 dominoes falldown  turkish domino record pt 2',
#  'full stream  yerry minas unveiling as a barça player',
#  'bird photobombs weather report',
#  'black mirror  featurette season 4  netflix',
#  'morning joe michael wolff cold open  snl',
#  'the handmaid’s tale season 2 first look official • only on hulu',
#  'i bought one snickers bar from every walmart',
#  'diy 5 pound potato skin  julia left jp',
#  'diy maple taffy on a stick is canada even real',
#  'making a lemon stun gun',
#  'can porcupine quills puncture an iphone x',
#  'exclusive reginae carter reveals what changed after that beef with khia',
#  'human flaming hot cheeto challenge',
#  'cantina theme played by rubiks cube whilst being solved  pencil girl parody',
#  'seeing allred  official trailer hd  netflix',
#  'why are koreans so obsessed with bitcoincryptocurrency',
#  'greys anatomy 14x09 promo 18007997233 hd season 14 episode 9 promo',
#  'melissa benoist reveals best part about playing supergirl',
#  'everything sucks  date announcement hd  netflix',
#  'penelope cruz tries to teach ellen spanish',
#  'keeping up with the kardashians katchup s14 ep14  e',
#  'kim kardashian and kanye west welcome baby girl via surrogate i tmz news',
#  '1992 skin bracer commercial wjack palance',
#  'adam  brees story  how couples sleep',
#  'where are we',
#  'learn to juggle 5 balls in 1 month  maxs monthly challenge',
#  '21 strangest movie translations in japanese',
#  'blade vs deacon frost lightsaber battle',
#  'asmr lushful spa treatment ✨ facial and massage',
#  'daniel kaluuya get out shows how white people say weird stuff',
#  'queer eye  official trailer hd  netflix',
#  'see with your ears spielberg and sound design',
#  'kuwtk  kourtney kardashian explains ex scotts reaction to her bf  e',
#  'jimmy kimmel goes undercover on reddit twitter  wikipedia  actually me  gq',
#  'nick jonas heart rate monitor feat selena gomez joe jonas  jack black  strong language',
#  'did kyle richards see kylie jenner’s baby bump  rhobh  wwhl',
#  'sarah jessica parker wants ellen to play samantha in the sex and the city movie',
#  'kind presents anna faris reads competitor protein bar reviews',
#  'what to leave in 2017',
#  'garry kasparov answers chess questions from twitter  tech support  wired',
#  'wont you be my neighbor  first look clip  coming soon',
#  'see 130 years of national geographic covers in under 2 minutes  national geographic',
#  'i am mlk jr official teaser  paramount network',
#  'how a tv works in slow motion  the slow mo guys',
#  'heathers official red band trailer  premieres march 7th on paramount network',
#  'we have the exclusive super troopers 2 trailer drop here and meow',
#  'saoirse ronan plays whod you rather',
#  'ricky gervais hosting the 2018 golden globes wouldve ended my career',
#  'is angelina jolie or jennifer aniston the better kisser  plead the fifth  wwhl',
#  'nerf pick your path challenge',
#  '70s ads after eight chocolate mints',
#  'black lightning  series premiere review black nerd',
#  'den of thieves  alpha males featurette  now playing',
#  'ive been shitposting a lot of memes lately',
#  'will the flash movie flashpoint be too comedic in tone  movie talk',
#  'inside issa rae’s lit malibu pool party part 12',
#  'timothée chalamet donates woody allen movie salary to times up  news flash  entertainment weekly',
#  'dakota fanning dishes on new psychological thriller the alienist',
#  'wanna be startin somethin w the stars  lip sync battle live a michael jackson celebration',
#  'jamie dornan had an awkward ‘james bond’ moment  the graham norton show',
#  'adam levine almost st himself while his wife was in labor',
#  'sharon stone is proof that women can play roles written for men',
#  'diddy speaks on new energy 50 cent mase the four  more',
#  'goodbye 3 million subscribers',
#  'melania trump sings part of your world little mermaid parody',
#  'winchester clip shows spooky house in helen mirrens haunting new movie',
#  'rita ora  proud official audio',
#  'chit chat grwm with winnie harlow',
#  'ikigai the japanese secret to a long and happy life',
#  'elders react to ugandan knuckles memes',
#  'helen mirren reunited with exboyfriend liam neeson  the graham norton show',
#  'jessica chastain monologue  snl',
#  'what even matters anymore  snl',
#  'ready player one  see the future',
#  'this is us press room qa  24th annual sag awards  tnt',
#  'magic transforming top coat does this thing even work',
#  'sean “diddy” combs on janet jackson and justin timberlake  wwhl',
#  'scarlett johansson womens march event full speech 2018 james franco natalie portman',
#  'getting wide like kylo ren',
#  '50 cent goes undercover on reddit twitter  instagram  actually me  gq',
#  'taye diggs slays candyman in front of christina aguilera  lip sync battle preview',
#  '10 best moments from 2018 sag awards',
#  'frances mcdormand acceptance speech  24th annual sag awards  tnt',
#  'quentin tarantino’s star trek nerdist presents',
#  'diy japanese fluffy pancakes',
#  'olivia munn  niecy nash hilariously stole the show at the 2018 sag awards  access',
#  'keeping up with the kardashians katchup s14 ep15  e',
#  'mm’s super bowl teaser 2018 featuring danny devito 15',
#  '5 things you missed at the 2018 sag awards  e news',
#  'the breakfast club addresses backlash after amara la negra interview',
#  'why are fat people a joke',
#  'corden on trump i spanked him',
#  'how to become tripadvisor’s 1 fake restaurant',
#  'im poppy  trailer',
#  'giving away my youtube adsense',
#  'beyond the routine jordyn wieber  the trailer',
#  'burger king  whopper neutrality',
#  'aaron paul reveals what not to say to your wife during labor',
#  'marvel studios black panther  kinetic energy film clip',
#  'seven seconds  official trailer hd  netflix',
#  'christina aguilera watches erika jayne crush “fighter”  lip sync battle',
#  'skittles  possible super bowl ad – sandwich',
#  'maisie williams heart rate monitor feat eddie redmayne  game of thrones season 8 spoilers ',
#  'our family mycalvins kardashian  jenner',
#  'entire breaking bad series in 1 minute',
#  'how not to sexually harass someone  the mash report  bbc two',
#  'john varvatos springsummer 2018 campaign featuring nick jonas jvxnj',
#  'idris elba thinks the world is ready for a black james bond',
#  'pantry essentials  basics with babish',
#  'are taco bells nacho fries worth the hype',
#  'kfc  honky tonk  smoky mountain bbq',
#  'lisa kudrow is handling her son going to college very well',
#  'rupaul and stephen share a secret language',
#  'groupon 2018 super bowl commercial  who wouldnt',
#  'pepsihalftime choreography bts  justin timberlake  pepsi',
#  'hollywood stunt falls in slow motion',
#  'the ghost in my house  morgan adams',
#  'the last jedi novelization to feature deleted scenes star wars day at sea and more',
#  'just a couple friends  acoustic music video',
#  'howto make a deadliest catch pineapple bowl with trap kitchen',
#  'steve brown says attacker was laughing before he stormed stage  tmz',
#  'mtb skills  technical climb',
#  'atv attempt to pull out the car ││ any rubbish',
#  'running through glass in slow motion',
#  'footage of how tom cruise broke his ankle while filming his latest movie  the graham norton show',
#  'stephens covetton house meets gwyneth paltrows goop',
#  'momsplaining with kristen bell kidspartygoals ep 2',
#  'viola davis on melania trumps love of how to get away with murder',
#  'chloe grace moretz on louis ck and the metoo movement',
#  'the hurricane heist trailer',
#  'james corden almost named his daughter beyoncé',
#  'tom cruise shows slowmo footage of how he broke his ankle  the graham norton show',
#  'the ritual  official trailer hd  netflix',
#  'call me by your name star timothee chalamet on the time he embarrassed himself with saoirse ronan',
#  'skittles  possible super bowl ad – floating',
#  'kendrick lamar  u2  dave chappelle   xxx  dna grammy 2018 performance',
#  'george w bush returns cold open  snl',
#  'james corden leads subway karaoke during the 2018 grammy awards',
#  'this bra makes you stronger weird as seen on tv procucts',
#  'mamma mia here we go again  grammys spot',
#  'john legend and tony bennett sing new york new york',
#  'budweiser 2018 super bowl commercial  “stand by you”',
#  'cardi b wants a grammy',
#  'pj morton first began official music video',
#  'hillary clinton cardi b  more audition for fire  fury  2018 grammys',
#  'cardi b has butterflies in her stomach  where  e live from the red carpet',
#  'when we first met  official trailer hd  netflix',
#  'kesha performs praying at 2018 grammys',
#  'nicole kidman eats bugs  secret talent theatre  vanity fair',
#  'the biggest moments from the 2018 grammys kesha bruno mars kendrick lamar  hillary clinton',
#  'fifth harmony’s ally brooke is selena and jlo  lip sync battle',
#  'wwe royal rumble 2018 review what went down',
#  'i threw myself a graduation ceremony',
#  'did alexa lose her voice  teaser  amazon super bowl commercial lii',
#  'inside the littiest pregrammy party',
#  'marvel studios antman and the wasp  official trailer',
#  'what does a giant monster neodymium magnet do to a mouse',
#  'childish gambino gives soulful terrified performance at 2018 grammys',
#  'shinsuke wins rumble  reaction  wwe royal rumble',
#  'this is us 2x14 promo super bowl sunday hd',
#  'stephen goes live after trumps state of the union',
#  'drop the mic w helen mirren',
#  'my therapist dr plier',
#  'the first purge announcement  in theaters july 4',
#  'kerry washington on scandal oprah  state of the union',
#  'universal studios for celebration of harry potter expo 2018  wb studio tour movie props  more',
#  'glee star mark salling dead of apparent suicide  tmz news',
#  'doritos blaze vs mtn dew ice  super bowl commercial with peter dinklage and morgan freeman',
#  'megan mullally didnt notice the interesting pattern with ellens roommates',
#  'spoiler alert 🌹🏁 krystal will you accept this ride  the bachelor insider',
#  'keith urban  female acoustic',
#  'mm’s super bowl commercial 2018 featuring danny devito – ‘human’ 30',
#  'saved by the max la ticket announcement',
#  'spoiler 1st eliminated queen rupauls all stars 3 behind the scenes',
#  'michelle obama talks with birthday girl ellen about postwhite house life',
#  'alexa loses her voice – leslie jones and jb smoove  “calling ashley”',
#  'melania trump gives her own state of the union',
#  'shopping for jugs  growing up hip hop atlanta  we tv',
#  'jamie dornan on his weebag  dakota johnson',
#  'lisa kudrow heard lindsay lohan wants to do the comeback',
#  'riverdale  chapter twentysix the telltale heart trailer  the cw',
#  'sharon stone as satc’s samantha jones  wwhl',
#  'jim gaffigan hijacks a strangers tinder  vanity fair',
#  'mr bean is a master of physical comedy',
#  'doritos blaze vs mtn dew ice  super bowl commercial with peter dinklage and morgan freeman',
#  'fifth harmony’s normani kordei performs bootylicious by destinys child   lip sync battle preview',
#  'the moment george clooney met amal  my next guest needs no introduction  netflix',
#  'when will we see the xmen in the mcu  sju',
#  'antman and the wasp trailer drops  black panther first reactions  movie talk',
#  'quick d invisible box challenge',
#  'breaking meeks lawyer fires back with proof judge favored old management',
#  'logan paul says hes still learning from suicide forest mistake  tmz',
#  'tom clancy’s jack ryan – super bowl commercial hd  prime video',
#  'the legend of red hand  short movie en',
#  'spiderman dancing take on me by aha  dj ivan davis',
#  'jennifer aniston drops by to wish ellen a happy birthday in person',
#  'spoiler 2nd eliminated queen rupauls all stars 3 behind the scenes',
#  'talkin football  jeopardy',
#  'irreplaceable you  official trailer hd  netflix',
#  'martin cast reunites plays it coy about tv reboot  tmz',
#  'jamie dornan used to live with desperate eddie redmayne',
#  'bud light  the bud knight',
#  'snokes throne room fight  16 bit scenes',
#  'sarah jessica parker on kim cattrall’s diss  wwhl',
#  'the dolan twins  brockhampton today  trl weekdays at 4pm',
#  'how horse sounds are made for movies',
#  'first responders arrive to the collapsed floor  season 1 ep 5  911',
#  'guacworld 60  2018 big game commercial  avocados from mexico',
#  'rooftop pov escape from hong kong security 🇭🇰',
#  'a special message from this is us promo',
#  'adults react to karma is a bitch challenge',
#  'natalies 2nd rap  snl',
#  'william’s mother wouldn’t let him be in michael jackson’s music video  the graham norton show',
#  'game night  official trailer',
#  'station 19  official trailer',
#  'rise of the tmnt official live stream character art reveal ft andre black nerd  kevin eastman',
#  'castle rock teaser 2 official • a hulu original',
#  'solo a star wars story big game tv spot 45',
#  'tide  super bowl lii 2018 commercial  its a tide ad',
#  'jurassic world fallen kingdom  official trailer 2 hd',
#  'marvel studios’ avengers infinity war  big game spot',
#  'the cloverfield paradox  watch now  netflix',
#  'tmobile  littleones  2018 big game ad',
#  'fox  friends cold open  snl',
#  'the blue marble',
#  'monster  super bowl commercial extended version',
#  'puppy bowl spot center top 5 plays',
#  'brad makes chocolate in ecuador part 1  its alive  bon appétit',
#  'rise  super bowl commercial',
#  'cocacola  the wonder of us 60',
#  'the voice 2018  super bowl commercial',
#  'mm’s – ‘mm’s again’ 15',
#  'reese witherspoon teaches you southern slang  secret talent theatre  vanity fair',
#  'budweiser  original whazzup ad',
#  'pepsi generations this is the pepsi  pepsi  extended',
#  'iceberg',
#  'backstage at the 2018 puppy bowl',
#  'budweiser  beer country  60',
#  'solo a star wars story official teaser',
#  'kevin hart wildn at super bowl after eagles win',
#  'melissa mccarthys new dogs are pretty but not that smart',
#  'this is us  aftershow season 2 episode 14 digital exclusive  presented by chevrolet',
#  'cardi bs so cold in minneapolis she can barely talk  tmz',
#  'can you recognize these songs when played backwards',
#  'normani kordei of fifth harmony channels destinys child for bootylicious  lip sync battle',
#  'amazon 2018 super bowl commercial  alexa loses her voice cardi b gordon ramsey',
#  'match the job to the person  lineup  cut',
#  'annalynne mccord',
#  'life of the party  official trailer 1',
#  'everything sucks  official trailer hd  netflix',
#  'gays on ice olympics edition ft adam rippon',
#  'claire danes and the homeland cast have spy camp',
#  'margot robbies date tonya harding owned the globes',
#  'katy perry watches fan covers on youtube  glamour',
#  'clint eastwood and reallife heroes from paris train attack',
#  'angela ryes big decision to freeze her eggs',
#  'did solo a star wars story trailer win over fans  movie talk',
#  'jamie dornans wife still hasnt seen any of the fifty shades films  lorraine',
#  'marvel’s jessica jones  season 2  official trailer hd  netflix',
#  'lady doritos',
#  'fifty shades of corden w jamie dornan',
#  'miranda kerr on having a baby with snapchats evan spiegel',
#  'johnny weir slays celine dion’s “my heart will go on”  lip sync battle preview',
#  'milo ventimiglia defends the crockpot',
#  'logan paul is back',
#  'cut for time my little step children natalie portman  snl',
#  'michael shannon puts 210 in coins up his nose  secret talent theatre  vanity fair',
#  'venom  official teaser trailer hd',
#  'pizza  basics with babish',
#  'john oliver warns meghan markle what shes getting herself into',
#  'horton hears a who  nostalgia critic',
#  'marvel studios 10th anniversary announcement – class photo video',
#  'amy schumer debuts her new film ‘i feel pretty’',
#  'this is what happens when you dont sleep in  will smith vlogs',
#  'meghan trainor  guillermo del toro rat enthusiasts',
#  'cecily strong on the snl audition process  wwhl',
#  'hang with timothée chalamet and armie hammer before the oscars  omaze',
#  'this week i learned to slingshot',
#  'jessica biel and chelsea handler take a little looksee full video',
#  'the grand tour season 2 episode 10 trailer',
#  'spoiler 3rd eliminated queen rupauls all stars 3 behind the scenes',
#  'yara shahidi is turning 18 and having a voting party',
#  'momsplaining with kristen bell productreviews with ryan hansen ep 5',
#  'dan stevens can make malt balls levitate',
#  'the talk  nicole eggert recounts abuse timeline by scott baio shares costars new claims filed',
#  'johnny weir channels lady gaga for paparazzi  lip sync battle',
#  'full actresses roundtable saoirse ronan jennifer lawrence mary j blige  close up with thr',
#  'got creators making new star wars films up close with the falcon and your solo teaser reactions',
#  'does melania trump like cecily strong’s snl impersonation  wwhl',
#  'ed sheeran tattoo’d saoirse ronan’s handwriting onto himself  the graham norton show',
#  'liam neesons cupid audition',
#  'khloe kardashian is continuing to workout during her pregnancy  lorraine',
#  'absolut  the vodka with nothing to hide',
#  'diy super long french fry  versus',
#  'i gave myself a kylie jenner makeover 💋',
#  'ernie designs a tattoo for his mom  kids draw  cut',
#  'hear the otherworldly sounds of skating on thin ice  national geographic',
#  'kuwtk  scott disick admits to dating 19yearold sofia richie  e',
#  'the future of flite test   help build our world of flight',
#  'how overnight shipping works',
#  'talking about my ghost with the psychic twins',
#  'atlanta  season 2 official trailer hd  fx',
#  '42000 match sphere gets lit',
#  'what working tech support is really like',
#  'black panther cast touches a chameleon a guinea pig and other weird stuff  fear box  vanity fair',
#  'jimmy kimmel interviews bekah m from the bachelor',
#  'a series of unfortunate events  season 2  official teaser hd  netflix',
#  'see lala and kways epic and hilarious danceoff  bet social awards',
#  'andy cohen weighs in on kim cattrall’s feud with sarah jessica parker',
#  'how claymation movies are made',
#  'kris jenner grills scott disick about dating sofia richie  watch',
#  'catt sadler shares her side of e exit  the view',
#  'donald trumps valentines day card to melania trump',
#  'the florida project shouldve been nominated',
#  'padma lakshmi on a topchef’s cancer diagnosis  wwhl',
#  'oscar isaac on being a new dad',
#  'little girls incredible valentines day rant',
#  'chloe kim road to pyeongchang',
#  'young king  black panther jaden smith parody nerdist presents',
#  'did beyonce have to check an actress talking to jayz  uncensored',
#  'ready player one  come with me',
#  'the talk  piers morgan goes off on omarosa from celebrity apprentice to the white house',
#  'lavar ball performs hate me now by nas ft puff daddy  lip sync battle preview',
#  'michael blackson goes after monique  bet social awards',
#  'meet americas oldest interracial newlyweds editheddie',
#  'descendants 3 teaser 💚💜',
#  'daniel kaluuya hugged oprah at the golden globes  the graham norton show',
#  'best reaction ever  mickey and minnie at drivethru  valentines day',
#  'firstever footage of cobra kai  the karate kid saga continues',
#  'spoiler 4th eliminated queen rupauls all stars 3 behind the scenes',
#  'red gerard on his gold medal snowboard run',
#  'momsplaining with kristen bell sparkjoy with marie kondo ep 6',
#  'black panther cast answers the webs most searched questions  wired',
#  'looking back',
#  'can ellen get steph  ayesha curry to reveal their babys gender',
#  'everything you need to know about zombies exclusive',
#  'black panther review  the women were clutch',
#  'how to make jollibee  versus',
#  'camilla cabello performs never be the same  dancing on ice 2018',
#  'weitsprung alyn camara im trex kostüm  teil 2  beginner gegen gewinner  prosieben',
#  'we lost him  will smith vlogs',
#  ...]

# %%
#Helper function to:
# 1) Tokenize words in dataset 
# 2) Convert data to seqence of tokens  
tokenizer = Tokenizer()

def get_sequence_of_tokens(corpus):
    tokenizer.fit_on_texts(corpus) #Each word in 'corpus' with be assigned an integer (Integer Encoding) (E.g. This:1, is:2,a:3, program:4)
    total_words = len(tokenizer.word_index) + 1     
    
    #Converting data to Seqence of tokens 
    input_sequences = []

    for line in corpus:
      token_list = tokenizer.texts_to_sequences([line])[0] #(E.g. [12,34,45,565,20]) #Sequence of tokens
      for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)  #N-gram: a sequence of N words 
    return input_sequences, total_words # All N-grame sequences and total number of words (around:16449) 


inp_sequences, total_words = get_sequence_of_tokens(corpus)

# %%
get_sequence_of_tokens(corpus)
# Out:
# ([[1, 92],
#   [1, 92, 4286],
#   [1, 92, 4286, 74],
#   [1, 92, 4286, 74, 373],
#   [1, 92, 4286, 74, 373, 1396],
#   [1, 92, 4286, 74, 373, 1396, 11],
#   [1, 92, 4286, 74, 373, 1396, 11, 140],
#   [1, 92, 4286, 74, 373, 1396, 11, 140, 1156],
#   [1, 92, 4286, 74, 373, 1396, 11, 140, 1156, 1713],
#   [6592, 1526],
#   [6592, 1526, 144],
#   [6592, 1526, 144, 95],
#   [6592, 1526, 144, 95, 411],
#   [35, 1918],
#   [35, 1918, 27],
#   [35, 1918, 27, 797],
#   [35, 1918, 27, 797, 6593],
#   [1157, 1056],
#   [1157, 1056, 2593],
#   [1157, 1056, 2593, 6594],
#   [1157, 1056, 2593, 6594, 434],
#   [1157, 1056, 2593, 6594, 434, 453],
#   [1157, 1056, 2593, 6594, 434, 453, 126],
#   [551, 3213],
#   [551, 3213, 2210],
#   [551, 3213, 2210, 1],
#   [551, 3213, 2210, 1, 83],
#   [551, 3213, 2210, 1, 83, 4287],
#   [551, 3213, 2210, 1, 83, 4287, 62],
#   [551, 3213, 2210, 1, 83, 4287, 62, 359],
#   [551, 3213, 2210, 1, 83, 4287, 62, 359, 14],
#   [551, 3213, 2210, 1, 83, 4287, 62, 359, 14, 4288],
#   [551, 3213, 2210, 1, 83, 4287, 62, 359, 14, 4288, 1],
#   [551, 3213, 2210, 1, 83, 4287, 62, 359, 14, 4288, 1, 603],
#   [551, 3213, 2210, 1, 83, 4287, 62, 359, 14, 4288, 1, 603, 391],
#   [2594, 1919],
#   [2594, 1919, 29],
#   [2594, 1919, 29, 2594],
#   [2594, 1919, 29, 2594, 1919],
#   [976, 169],
#   [976, 169, 4289],
#   [976, 169, 4289, 16],
#   [976, 169, 4289, 16, 2595],
#   [976, 169, 4289, 16, 2595, 1714],
#   [604, 454],
#   [604, 454, 5],
#   [604, 454, 5, 6595],
#   [604, 454, 5, 6595, 605],
#   [96, 127],
#   [96, 127, 1397],
#   [96, 127, 1397, 1],
#   [96, 127, 1397, 1, 6596],
#   [96, 127, 1397, 1, 6596, 6597],
#   [96, 127, 1397, 1, 6596, 6597, 3214],
#   [96, 127, 1397, 1, 6596, 6597, 3214, 2596],
#   [96, 127, 1397, 1, 6596, 6597, 3214, 2596, 127],
#   [96, 127, 1397, 1, 6596, 6597, 3214, 2596, 127, 1397],
#   [751, 37],
#   [751, 37, 4],
#   [751, 37, 4, 314],
#   [751, 37, 4, 314, 134],
#   [751, 37, 4, 314, 134, 4290],
#   [751, 37, 4, 314, 134, 4290, 6598],
#   [751, 37, 4, 314, 134, 4290, 6598, 6599],
#   [80, 69],
#   [80, 69, 6600],
#   [80, 69, 6600, 752],
#   [80, 69, 6600, 752, 573],
#   [80, 69, 6600, 752, 573, 6601],
#   [80, 69, 6600, 752, 573, 6601, 193],
#   [80, 69, 6600, 752, 573, 6601, 193, 2211],
#   [80, 69, 6600, 752, 573, 6601, 193, 2211, 3215],
#   [80, 69, 6600, 752, 573, 6601, 193, 2211, 3215, 8],
#   [80, 69, 6600, 752, 573, 6601, 193, 2211, 3215, 8, 1398],
#   [80, 69, 6600, 752, 573, 6601, 193, 2211, 3215, 8, 1398, 3216],
#   [858, 2597],
#   [858, 2597, 2598],
#   [858, 2597, 2598, 2212],
#   [858, 2597, 2598, 2212, 3217],
#   [858, 2597, 2598, 2212, 3217, 11],
#   [858, 2597, 2598, 2212, 3217, 11, 1158],
#   [858, 2597, 2598, 2212, 3217, 11, 1158, 6602],
#   [858, 2597, 2598, 2212, 3217, 11, 1158, 6602, 1],
#   [858, 2597, 2598, 2212, 3217, 11, 1158, 6602, 1, 162],
#   [858, 2597, 2598, 2212, 3217, 11, 1158, 6602, 1, 162, 168],
#   [858, 2597, 2598, 2212, 3217, 11, 1158, 6602, 1, 162, 168, 39],
#   [6603, 552],
#   [6603, 552, 13],
#   [6603, 552, 13, 63],
#   [6603, 552, 13, 63, 133],
#   [6604, 3218],
#   [6604, 3218, 27],
#   [6604, 3218, 27, 9],
#   [6604, 3218, 27, 9, 403],
#   [1920, 2213],
#   [1920, 2213, 60],
#   [1920, 2213, 60, 6605],
#   [1920, 2213, 60, 6605, 244],
#   [1920, 2213, 60, 6605, 244, 23],
#   [1920, 2213, 60, 6605, 244, 23, 3],
#   [190, 3219],
#   [190, 3219, 4291],
#   [190, 3219, 4291, 977],
#   [190, 3219, 4291, 977, 374],
#   [190, 3219, 4291, 977, 374, 4],
#   [190, 3219, 4291, 977, 374, 4, 374],
#   [190, 3219, 4291, 977, 374, 4, 374, 11],
#   [190, 3219, 4291, 977, 374, 4, 374, 11, 43],
#   [190, 3219, 4291, 977, 374, 4, 374, 11, 43, 6606],
#   [190, 3219, 4291, 977, 374, 4, 374, 11, 43, 6606, 6607],
#   [190, 3219, 4291, 977, 374, 4, 374, 11, 43, 6606, 6607, 1527],
#   [978, 4],
#   [978, 4, 979],
#   [978, 4, 979, 5],
#   [978, 4, 979, 5, 636],
#   [978, 4, 979, 5, 636, 4292],
#   [978, 4, 979, 5, 636, 4292, 6608],
#   [978, 4, 979, 5, 636, 4292, 6608, 14],
#   [978, 4, 979, 5, 636, 4292, 6608, 14, 4293],
#   [435, 532],
#   [435, 532, 1528],
#   [435, 532, 1528, 503],
#   [435, 532, 1528, 503, 436],
#   [435, 532, 1528, 503, 436, 1529],
#   [435, 532, 1528, 503, 436, 1529, 103],
#   [435, 532, 1528, 503, 436, 1529, 103, 1],
#   [435, 532, 1528, 503, 436, 1529, 103, 1, 140],
#   [435, 532, 1528, 503, 436, 1529, 103, 1, 140, 1255],
#   [435, 532, 1528, 503, 436, 1529, 103, 1, 140, 1255, 39],
#   [6609, 6610],
#   [6609, 6610, 6],
#   [6609, 6610, 6, 360],
#   [6609, 6610, 6, 360, 3220],
#   [6609, 6610, 6, 360, 3220, 6611],
#   [6609, 6610, 6, 360, 3220, 6611, 6612],
#   [6609, 6610, 6, 360, 3220, 6611, 6612, 48],
#   [6609, 6610, 6, 360, 3220, 6611, 6612, 48, 265],
#   [858, 2597],
#   [858, 2597, 1715],
#   [858, 2597, 1715, 6613],
#   [858, 2597, 1715, 6613, 109],
#   [858, 2597, 1715, 6613, 109, 32],
#   [858, 2597, 1715, 6613, 109, 32, 132],
#   [858, 2597, 1715, 6613, 109, 32, 132, 6614],
#   [2214, 284],
#   [2214, 284, 4294],
#   [2214, 284, 4294, 2599],
#   [2214, 284, 4294, 2599, 60],
#   [2214, 284, 4294, 2599, 60, 4295],
#   [574, 909],
#   [574, 909, 6615],
#   [574, 909, 6615, 3221],
#   [574, 909, 6615, 3221, 6616],
#   [574, 909, 6615, 3221, 6616, 437],
#   [574, 909, 6615, 3221, 6616, 437, 302],
#   [2600, 910],
#   [2600, 910, 16],
#   [2600, 910, 16, 2215],
#   [2600, 910, 16, 2215, 911],
#   [2600, 910, 16, 2215, 911, 1256],
#   [2600, 910, 16, 2215, 911, 1256, 122],
#   [2600, 910, 16, 2215, 911, 1256, 122, 21],
#   [2600, 910, 16, 2215, 911, 1256, 122, 21, 105],
#   [2601, 2602],
#   [2601, 2602, 6],
#   [2601, 2602, 6, 1716],
#   [2601, 2602, 6, 1716, 2603],
#   [2601, 2602, 6, 1716, 2603, 4296],
#   [2601, 2602, 6, 1716, 2603, 4296, 12],
#   [2601, 2602, 6, 1716, 2603, 4296, 12, 6617],
#   [2601, 2602, 6, 1716, 2603, 4296, 12, 6617, 3222],
#   [3223, 4297],
#   [3223, 4297, 662],
#   [3223, 4297, 662, 1921],
#   [3223, 4297, 662, 1921, 6618],
#   [3223, 4297, 662, 1921, 6618, 32],
#   [3223, 4297, 662, 1921, 6618, 32, 606],
#   [35, 2604],
#   [35, 2604, 4],
#   [35, 2604, 4, 1922],
#   [35, 2604, 4, 1922, 1920],
#   [35, 2604, 4, 1922, 1920, 6619],
#   [35, 2604, 4, 1922, 1920, 6619, 435],
#   [35, 2604, 4, 1922, 1920, 6619, 435, 532],
#   [607, 6620],
#   [607, 6620, 1923],
#   [607, 6620, 1923, 1399],
#   [607, 6620, 1923, 1399, 62],
#   [607, 6620, 1923, 1399, 62, 3224],
#   [607, 6620, 1923, 1399, 62, 3224, 7],
#   [607, 6620, 1923, 1399, 62, 3224, 7, 1],
#   [607, 6620, 1923, 1399, 62, 3224, 7, 1, 2216],
#   [607, 6620, 1923, 1399, 62, 3224, 7, 1, 2216, 3225],
#   [607, 6620, 1923, 1399, 62, 3224, 7, 1, 2216, 3225, 3226],
#   [607, 6620, 1923, 1399, 62, 3224, 7, 1, 2216, 3225, 3226, 5],
#   [607, 6620, 1923, 1399, 62, 3224, 7, 1, 2216, 3225, 3226, 5, 118],
#   [753, 663],
#   [753, 663, 1717],
#   [753, 663, 1717, 6],
#   [753, 663, 1717, 6, 6621],
#   [753, 663, 1717, 6, 6621, 6622],
#   [753, 663, 1717, 6, 6621, 6622, 91],
#   [753, 663, 1717, 6, 6621, 6622, 91, 90],
#   [753, 663, 1717, 6, 6621, 6622, 91, 90, 375],
#   [753, 663, 1717, 6, 6621, 6622, 91, 90, 375, 4298],
#   [753, 663, 1717, 6, 6621, 6622, 91, 90, 375, 4298, 61],
#   [753, 663, 1717, 6, 6621, 6622, 91, 90, 375, 4298, 61, 1159],
#   [753, 663, 1717, 6, 6621, 6622, 91, 90, 375, 4298, 61, 1159, 173],
#   [5, 83],
#   [5, 83, 8],
#   [5, 83, 8, 1],
#   [5, 83, 8, 1, 138],
#   [5, 83, 8, 1, 138, 7],
#   [5, 83, 8, 1, 138, 7, 798],
#   [5, 83, 8, 1, 138, 7, 798, 4299],
#   [59, 8],
#   [59, 8, 1],
#   [59, 8, 1, 315],
#   [1057, 21],
#   [1057, 21, 23],
#   [1057, 21, 23, 24],
#   [1057, 21, 23, 24, 103],
#   [912, 22],
#   [912, 22, 6623],
#   [912, 22, 6623, 1400],
#   [912, 22, 6623, 1400, 346],
#   [2605, 12],
#   [2605, 12, 4300],
#   [2605, 12, 4300, 5],
#   [2605, 12, 4300, 5, 2217],
#   [2605, 12, 4300, 5, 2217, 1924],
#   [2605, 12, 4300, 5, 2217, 1924, 32],
#   [2605, 12, 4300, 5, 2217, 1924, 32, 4301],
#   [2605, 12, 4300, 5, 2217, 1924, 32, 4301, 4302],
#   [35, 438],
#   [35, 438, 1],
#   [35, 438, 1, 215],
#   [35, 438, 1, 215, 574],
#   [3227, 3228],
#   [3227, 3228, 1530],
#   [3227, 3228, 1530, 21],
#   [3227, 3228, 1530, 21, 1718],
#   [336, 1925],
#   [336, 1925, 6624],
#   [336, 1925, 6624, 2218],
#   [336, 1925, 6624, 2218, 7],
#   [336, 1925, 6624, 2218, 7, 1],
#   [336, 1925, 6624, 2218, 7, 1, 913],
#   [336, 1925, 6624, 2218, 7, 1, 913, 5],
#   [336, 1925, 6624, 2218, 7, 1, 913, 5, 134],
#   [336, 1925, 6624, 2218, 7, 1, 913, 5, 134, 504],
#   [336, 1925, 6624, 2218, 7, 1, 913, 5, 134, 504, 6625],
#   [336, 1925, 6624, 2218, 7, 1, 913, 5, 134, 504, 6625, 59],
#   [336, 1925, 6624, 2218, 7, 1, 913, 5, 134, 504, 6625, 59, 39],
#   [336, 1925, 6624, 2218, 7, 1, 913, 5, 134, 504, 6625, 59, 39, 36],
#   [637, 638],
#   [637, 638, 303],
#   [637, 638, 303, 3229],
#   [637, 638, 303, 3229, 275],
#   [637, 638, 303, 3229, 275, 361],
#   [637, 638, 303, 3229, 275, 361, 6626],
#   [637, 638, 303, 3229, 275, 361, 6626, 4],
#   [637, 638, 303, 3229, 275, 361, 6626, 4, 505],
#   [637, 638, 303, 3229, 275, 361, 6626, 4, 505, 4303],
#   [637, 638, 303, 3229, 275, 361, 6626, 4, 505, 4303, 376],
#   [637, 638, 303, 3229, 275, 361, 6626, 4, 505, 4303, 376, 194],
#   [6627, 6628],
#   [6627, 6628, 161],
#   [6627, 6628, 161, 62],
#   [6627, 6628, 161, 62, 43],
#   [6627, 6628, 161, 62, 43, 977],
#   [6627, 6628, 161, 62, 43, 977, 87],
#   [6627, 6628, 161, 62, 43, 977, 87, 639],
#   [6627, 6628, 161, 62, 43, 977, 87, 639, 87],
#   [6627, 6628, 161, 62, 43, 977, 87, 639, 87, 62],
#   [6627, 6628, 161, 62, 43, 977, 87, 639, 87, 62, 43],
#   [6627, 6628, 161, 62, 43, 977, 87, 639, 87, 62, 43, 2606],
#   [6627, 6628, 161, 62, 43, 977, 87, 639, 87, 62, 43, 2606, 6629],
#   [6627, 6628, 161, 62, 43, 977, 87, 639, 87, 62, 43, 2606, 6629, 61],
#   [2607, 1719],
#   [2607, 1719, 161],
#   [2607, 1719, 161, 3230],
#   [2607, 1719, 161, 3230, 8],
#   [2607, 1719, 161, 3230, 8, 132],
#   [2607, 1719, 161, 3230, 8, 132, 177],
#   [754, 6630],
#   [754, 6630, 10],
#   [754, 6630, 10, 4304],
#   [754, 6630, 10, 4304, 6631],
#   [754, 6630, 10, 4304, 6631, 8],
#   [754, 6630, 10, 4304, 6631, 8, 178],
#   [754, 6630, 10, 4304, 6631, 8, 178, 1531],
#   [754, 6630, 10, 4304, 6631, 8, 178, 1531, 4305],
#   [754, 6630, 10, 4304, 6631, 8, 178, 1531, 4305, 163],
#   [754, 6630, 10, 4304, 6631, 8, 178, 1531, 4305, 163, 2219],
#   [754, 6630, 10, 4304, 6631, 8, 178, 1531, 4305, 163, 2219, 83],
#   [914, 3231],
#   [914, 3231, 303],
#   [914, 3231, 303, 5],
#   [914, 3231, 303, 5, 1257],
#   [914, 3231, 303, 5, 1257, 216],
#   [1401, 608],
#   [1401, 608, 6632],
#   [1401, 608, 6632, 533],
#   [1401, 608, 6632, 533, 1058],
#   [1059, 1060],
#   [1059, 1060, 4306],
#   [1059, 1060, 4306, 4306],
#   [1059, 1060, 4306, 4306, 392],
#   [1059, 1060, 4306, 4306, 392, 1],
#   [1059, 1060, 4306, 4306, 392, 1, 506],
#   [1059, 1060, 4306, 4306, 392, 1, 506, 11],
#   [1059, 1060, 4306, 4306, 392, 1, 506, 11, 553],
#   [1059, 1060, 4306, 4306, 392, 1, 506, 11, 553, 321],
#   [1532, 1926],
#   [1532, 1926, 1061],
#   [1532, 1926, 1061, 3232],
#   [1532, 1926, 1061, 3232, 12],
#   [1532, 1926, 1061, 3232, 12, 69],
#   [1532, 1926, 1061, 3232, 12, 69, 6633],
#   [1532, 1926, 1061, 3232, 12, 69, 6633, 129],
#   [1532, 1926, 1061, 3232, 12, 69, 6633, 129, 10],
#   [1532, 1926, 1061, 3232, 12, 69, 6633, 129, 10, 799],
#   [1532, 1926, 1061, 3232, 12, 69, 6633, 129, 10, 799, 59],
#   [1532, 1926, 1061, 3232, 12, 69, 6633, 129, 10, 799, 59, 3233],
#   [70, 4],
#   [70, 4, 71],
#   [70, 4, 71, 1258],
#   [70, 4, 71, 1258, 404],
#   [70, 4, 71, 1258, 404, 75],
#   [70, 4, 71, 1258, 404, 75, 181],
#   [70, 4, 71, 1258, 404, 75, 181, 1399],
#   [70, 4, 71, 1258, 404, 75, 181, 1399, 4],
#   [70, 4, 71, 1258, 404, 75, 181, 1399, 4, 71],
#   [70, 4, 71, 1258, 404, 75, 181, 1399, 4, 71, 11],
#   [70, 4, 71, 1258, 404, 75, 181, 1399, 4, 71, 11, 1],
#   [70, 4, 71, 1258, 404, 75, 181, 1399, 4, 71, 11, 1, 6634],
#   [70, 4, 71, 1258, 404, 75, 181, 1399, 4, 71, 11, 1, 6634, 6635],
#   [70, 4, 71, 1258, 404, 75, 181, 1399, 4, 71, 11, 1, 6634, 6635, 6636],
#   [70, 4, 71, 1258, 404, 75, 181, 1399, 4, 71, 11, 1, 6634, 6635, 6636, 6637],
#   [476, 393],
#   [476, 393, 4307],
#   [476, 393, 4307, 3234],
#   [476, 393, 4307, 3234, 1720],
#   [476, 393, 4307, 3234, 1720, 1],
#   [476, 393, 4307, 3234, 1720, 1, 476],
#   [476, 393, 4307, 3234, 1720, 1, 476, 393],
#   [476, 393, 4307, 3234, 1720, 1, 476, 393, 1062],
#   [858, 2597],
#   [858, 2597, 285],
#   [858, 2597, 285, 296],
#   [858, 2597, 285, 296, 43],
#   [858, 2597, 285, 296, 43, 4308],
#   [858, 2597, 285, 296, 43, 4308, 6638],
#   [858, 2597, 285, 296, 43, 4308, 6638, 1],
#   [858, 2597, 285, 296, 43, 4308, 6638, 1, 162],
#   [858, 2597, 285, 296, 43, 4308, 6638, 1, 162, 168],
#   [858, 2597, 285, 296, 43, 4308, 6638, 1, 162, 168, 39],
#   [120, 47],
#   [120, 47, 202],
#   [120, 47, 202, 19],
#   [120, 47, 202, 19, 13],
#   [120, 47, 202, 19, 13, 1],
#   [120, 47, 202, 19, 13, 1, 4309],
#   [120, 47, 202, 19, 13, 1, 4309, 7],
#   [120, 47, 202, 19, 13, 1, 4309, 7, 4310],
#   [120, 47, 202, 19, 13, 1, 4309, 7, 4310, 4311],
#   [120, 47, 202, 19, 13, 1, 4309, 7, 4310, 4311, 23],
#   [120, 47, 202, 19, 13, 1, 4309, 7, 4310, 4311, 23, 24],
#   [15, 138],
#   [15, 138, 1259],
#   [15, 138, 1259, 27],
#   [15, 138, 1259, 27, 375],
#   [15, 138, 1259, 27, 375, 4],
#   [15, 138, 1259, 27, 375, 4, 88],
#   [15, 138, 1259, 27, 375, 4, 88, 11],
#   [15, 138, 1259, 27, 375, 4, 88, 11, 225],
#   [15, 138, 1259, 27, 375, 4, 88, 11, 225, 37],
#   [436, 1533],
#   [436, 1533, 3235],
#   [436, 1533, 3235, 3236],
#   [436, 1533, 3235, 3236, 4],
#   [436, 1533, 3235, 3236, 4, 46],
#   [436, 1533, 3235, 3236, 4, 46, 203],
#   [297, 2220],
#   [297, 2220, 2221],
#   [297, 2220, 2221, 88],
#   [297, 2220, 2221, 88, 439],
#   [297, 2220, 2221, 88, 439, 1534],
#   [297, 2220, 2221, 88, 439, 1534, 2222],
#   [297, 2220, 2221, 88, 439, 1534, 2222, 22],
#   [297, 2220, 2221, 88, 439, 1534, 2222, 22, 3237],
#   [297, 2220, 2221, 88, 439, 1534, 2222, 22, 3237, 2608],
#   [297, 2220, 2221, 88, 439, 1534, 2222, 22, 3237, 2608, 266],
#   [297, 2220, 2221, 88, 439, 1534, 2222, 22, 3237, 2608, 266, 915],
#   [297, 2220, 2221, 88, 439, 1534, 2222, 22, 3237, 2608, 266, 915, 800],
#   [297, 2220, 2221, 88, 439, 1534, 2222, 22, 3237, 2608, 266, 915, 800, 507],
#   [6639, 22],
#   [6639, 22, 3238],
#   [6639, 22, 3238, 1260],
#   [4312, 2609],
#   [4312, 2609, 4313],
#   [4312, 2609, 4313, 2223],
#   [4312, 2609, 4313, 2223, 321],
#   [4312, 2609, 4313, 2223, 321, 609],
#   [4312, 2609, 4313, 2223, 321, 609, 11],
#   [4312, 2609, 4313, 2223, 321, 609, 11, 1],
#   [4312, 2609, 4313, 2223, 321, 609, 11, 1, 191],
#   [3239, 6640],
#   [3239, 6640, 1063],
#   [3239, 6640, 1063, 6],
#   [3239, 6640, 1063, 6, 6641],
#   [3239, 6640, 1063, 6, 6641, 11],
#   [3239, 6640, 1063, 6, 6641, 11, 1535],
#   [574, 909],
#   [574, 909, 799],
#   [574, 909, 799, 202],
#   [574, 909, 799, 202, 3240],
#   [574, 909, 799, 202, 3240, 4314],
#   [65, 96],
#   [65, 96, 1927],
#   [65, 96, 1927, 170],
#   [65, 96, 1927, 170, 6642],
#   [65, 96, 1927, 170, 6642, 9],
#   [65, 96, 1927, 170, 6642, 9, 197],
#   [65, 96, 1927, 170, 6642, 9, 197, 1261],
#   [65, 96, 1927, 170, 6642, 9, 197, 1261, 197],
#   [65, 96, 1927, 170, 6642, 9, 197, 1261, 197, 123],
#   [65, 96, 1927, 170, 6642, 9, 197, 1261, 197, 123, 185],
#   [6643, 3241],
#   [6643, 3241, 916],
#   [6643, 3241, 916, 917],
#   [6643, 3241, 916, 917, 286],
#   [6643, 3241, 916, 917, 286, 1536],
#   [6643, 3241, 916, 917, 286, 1536, 9],
#   [6643, 3241, 916, 917, 286, 1536, 9, 13],
#   [6643, 3241, 916, 917, 286, 1536, 9, 13, 8],
#   [6643, 3241, 916, 917, 286, 1536, 9, 13, 8, 6644],
#   [6643, 3241, 916, 917, 286, 1536, 9, 13, 8, 6644, 1402],
#   [6643, 3241, 916, 917, 286, 1536, 9, 13, 8, 6644, 1402, 477],
#   [6643, 3241, 916, 917, 286, 1536, 9, 13, 8, 6644, 1402, 477, 455],
#   [1403, 4315],
#   [1403, 4315, 4315],
#   [1403, 4315, 4315, 111],
#   [1403, 4315, 4315, 111, 918],
#   [1403, 4315, 4315, 111, 918, 4316],
#   [1403, 4315, 4315, 111, 918, 4316, 664],
#   [1403, 4315, 4315, 111, 918, 4316, 664, 914],
#   [1403, 4315, 4315, 111, 918, 4316, 664, 914, 665],
#   [1403, 4315, 4315, 111, 918, 4316, 664, 914, 665, 606],
#   [435, 532],
#   [435, 532, 6645],
#   [435, 532, 6645, 6646],
#   [435, 532, 6645, 6646, 2610],
#   [435, 532, 6645, 6646, 2610, 2224],
#   [435, 532, 6645, 6646, 2610, 2224, 6647],
#   [435, 532, 6645, 6646, 2610, 2224, 6647, 1928],
#   [435, 532, 6645, 6646, 2610, 2224, 6647, 1928, 4317],
#   [435, 532, 6645, 6646, 2610, 2224, 6647, 1928, 4317, 1537],
#   [435, 532, 6645, 6646, 2610, 2224, 6647, 1928, 4317, 1537, 1160],
#   [435, 532, 6645, 6646, 2610, 2224, 6647, 1928, 4317, 1537, 1160, 6648],
#   [435, 532, 6645, 6646, 2610, 2224, 6647, 1928, 4317, 1537, 1160, 6648, 6649],
#   [3242, 666],
#   [3242, 666, 190],
#   [3242, 666, 190, 129],
#   [20, 7],
#   [20, 7, 6650],
#   [20, 7, 6650, 76],
#   [20, 7, 6650, 76, 1404],
#   [20, 7, 6650, 76, 1404, 1],
#   [20, 7, 6650, 76, 1404, 1, 267],
#   [20, 7, 6650, 76, 1404, 1, 267, 165],
#   [3224, 7],
#   [3224, 7, 1],
#   [3224, 7, 1, 2216],
#   [3224, 7, 1, 2216, 25],
#   [3224, 7, 1, 2216, 25, 40],
#   [3224, 7, 1, 2216, 25, 40, 303],
#   [3224, 7, 1, 2216, 25, 40, 303, 6651],
#   [3224, 7, 1, 2216, 25, 40, 303, 6651, 1929],
#   [3224, 7, 1, 2216, 25, 40, 303, 6651, 1929, 32],
#   [3224, 7, 1, 2216, 25, 40, 303, 6651, 1929, 32, 976],
#   [3224, 7, 1, 2216, 25, 40, 303, 6651, 1929, 32, 976, 171],
#   [3224, 7, 1, 2216, 25, 40, 303, 6651, 1929, 32, 976, 171, 347],
#   [3224, 7, 1, 2216, 25, 40, 303, 6651, 1929, 32, 976, 171, 347, 2225],
#   [3224, 7, 1, 2216, 25, 40, 303, 6651, 1929, 32, 976, 171, 347, 2225, 801],
#   [42, 1405],
#   [42, 1405, 153],
#   [42, 1405, 153, 75],
#   [42, 1405, 153, 75, 667],
#   [42, 1405, 153, 75, 667, 4],
#   [42, 1405, 153, 75, 667, 4, 1064],
#   [42, 1405, 153, 75, 667, 4, 1064, 3243],
#   [42, 1405, 153, 75, 667, 4, 1064, 3243, 174],
#   [42, 1405, 153, 75, 667, 4, 1064, 3243, 174, 4318],
#   [42, 1405, 153, 75, 667, 4, 1064, 3243, 174, 4318, 6],
#   [42, 1405, 153, 75, 667, 4, 1064, 3243, 174, 4318, 6, 43],
#   [42, 1405, 153, 75, 667, 4, 1064, 3243, 174, 4318, 6, 43, 919],
#   [42, 1405, 153, 75, 667, 4, 1064, 3243, 174, 4318, 6, 43, 919, 377],
#   [42, 1405, 153, 75, 667, 4, 1064, 3243, 174, 4318, 6, 43, 919, 377, 1538],
#   [6652, 1721],
#   [6652, 1721, 1539],
#   [435, 532],
#   [435, 532, 63],
#   [435, 532, 63, 133],
#   [245, 223],
#   [245, 223, 1406],
#   [245, 223, 1406, 1262],
#   [245, 223, 1406, 1262, 7],
#   [245, 223, 1406, 1262, 7, 2226],
#   [245, 223, 1406, 1262, 7, 2226, 802],
#   [245, 223, 1406, 1262, 7, 2226, 802, 4319],
#   [3244, 798],
#   [3244, 798, 4320],
#   [3244, 798, 4320, 122],
#   [3244, 798, 4320, 122, 1161],
#   [3244, 798, 4320, 122, 1161, 1065],
#   [3244, 798, 4320, 122, 1161, 1065, 62],
#   [3244, 798, 4320, 122, 1161, 1065, 62, 378],
#   [3244, 798, 4320, 122, 1161, 1065, 62, 378, 534],
#   [1162, 1930],
#   [1162, 1930, 2227],
#   [1162, 1930, 2227, 6653],
#   [1162, 1930, 2227, 6653, 6654],
#   [1162, 1930, 2227, 6653, 6654, 175],
#   [1162, 1930, 2227, 6653, 6654, 175, 6655],
#   [1162, 1930, 2227, 6653, 6654, 175, 6655, 105],
#   [70, 4],
#   [70, 4, 176],
#   [70, 4, 176, 237],
#   [70, 4, 176, 237, 6656],
#   [637, 1066],
#   [637, 1066, 379],
#   [637, 1066, 379, 1407],
#   [637, 1066, 379, 1407, 48],
#   [637, 1066, 379, 1407, 48, 2611],
#   [637, 1066, 379, 1407, 48, 2611, 6657],
#   [637, 1066, 379, 1407, 48, 2611, 6657, 4],
#   [637, 1066, 379, 1407, 48, 2611, 6657, 4, 4321],
#   [637, 1066, 379, 1407, 48, 2611, 6657, 4, 4321, 194],
#   [245, 223],
#   [245, 223, 711],
#   [245, 223, 711, 48],
#   [245, 223, 711, 48, 6658],
#   [245, 223, 711, 48, 6658, 4322],
#   [245, 223, 711, 48, 6658, 4322, 1722],
#   [245, 223, 711, 48, 6658, 4322, 1722, 1931],
#   [435, 532],
#   [435, 532, 63],
#   [435, 532, 63, 133],
#   [435, 532, 63, 133, 22],
#   [435, 532, 63, 133, 22, 69],
#   [435, 532, 63, 133, 22, 69, 72],
#   [435, 532, 63, 133, 22, 69, 72, 2612],
#   [435, 532, 63, 133, 22, 69, 72, 2612, 755],
#   [435, 532, 63, 133, 22, 69, 72, 2612, 755, 4323],
#   [435, 532, 63, 133, 22, 69, 72, 2612, 755, 4323, 9],
#   [6659, 1],
#   [6659, 1, 6660],
#   [6659, 1, 6660, 7],
#   [6659, 1, 6660, 7, 6661],
#   [6659, 1, 6660, 7, 6661, 980],
#   [6659, 1, 6660, 7, 6661, 980, 185],
#   [6659, 1, 6660, 7, 6661, 980, 185, 1723],
#   [4324, 2613],
#   [4324, 2613, 22],
#   [4324, 2613, 22, 6],
#   [4324, 2613, 22, 6, 26],
#   [4324, 2613, 22, 6, 26, 7],
#   [4324, 2613, 22, 6, 26, 7, 1],
#   [4324, 2613, 22, 6, 26, 7, 1, 163],
#   [454, 6662],
#   [454, 6662, 6663],
#   [454, 6662, 6663, 4325],
#   [454, 6662, 6663, 4325, 4326],
#   [4327, 2609],
#   [4327, 2609, 4328],
#   [4327, 2609, 4328, 2223],
#   [4327, 2609, 4328, 2223, 321],
#   [4327, 2609, 4328, 2223, 321, 609],
#   [4327, 2609, 4328, 2223, 321, 609, 11],
#   [4327, 2609, 4328, 2223, 321, 609, 11, 1],
#   [4327, 2609, 4328, 2223, 321, 609, 11, 1, 191],
#   [3224, 7],
#   [3224, 7, 1],
#   [3224, 7, 1, 2216],
#   [3224, 7, 1, 2216, 25],
#   [3224, 7, 1, 2216, 25, 40],
#   [3224, 7, 1, 2216, 25, 40, 3245],
#   [3224, 7, 1, 2216, 25, 40, 3245, 32],
#   [3224, 7, 1, 2216, 25, 40, 3245, 32, 976],
#   [3224, 7, 1, 2216, 25, 40, 3245, 32, 976, 80],
#   [3224, 7, 1, 2216, 25, 40, 3245, 32, 976, 80, 4329],
#   [3224, 7, 1, 2216, 25, 40, 3245, 32, 976, 80, 4329, 28],
#   [3224, 7, 1, 2216, 25, 40, 3245, 32, 976, 80, 4329, 28, 756],
#   [4330, 21],
#   [4330, 21, 23],
#   [4330, 21, 23, 51],
#   [4330, 21, 23, 51, 24],
#   [2228, 85],
#   [2228, 85, 1540],
#   [2228, 85, 1540, 95],
#   [2228, 85, 1540, 95, 2229],
#   [2228, 85, 1540, 95, 2229, 85],
#   [2228, 85, 1540, 95, 2229, 85, 1540],
#   [2228, 85, 1540, 95, 2229, 85, 1540, 246],
#   [2228, 85, 1540, 95, 2229, 85, 1540, 246, 245],
#   [2228, 85, 1540, 95, 2229, 85, 1540, 246, 245, 223],
#   [2614, 412],
#   [2614, 412, 2615],
#   [2614, 412, 2615, 5],
#   [2614, 412, 2615, 5, 917],
#   [2614, 412, 2615, 5, 917, 1263],
#   [2614, 412, 2615, 5, 917, 1263, 477],
#   [2614, 412, 2615, 5, 917, 1263, 477, 455],
#   [1724, 272],
#   [1724, 272, 11],
#   [1724, 272, 11, 1541],
#   [1724, 272, 11, 1541, 2230],
#   [1724, 272, 11, 1541, 2230, 606],
#   [610, 3246],
#   [610, 3246, 4331],
#   [610, 3246, 4331, 5],
#   [610, 3246, 4331, 5, 208],
#   [610, 3246, 4331, 5, 208, 67],
#   [610, 3246, 4331, 5, 208, 67, 268],
#   [610, 3246, 4331, 5, 208, 67, 268, 4332],
#   [1, 166],
#   [1, 166, 712],
#   [1, 166, 712, 276],
#   [1, 166, 712, 276, 4],
#   [1, 166, 712, 276, 4, 911],
#   [1, 166, 712, 276, 4, 911, 3247],
#   [1, 166, 712, 276, 4, 911, 3247, 6664],
#   [1, 166, 712, 276, 4, 911, 3247, 6664, 4333],
#   [1, 166, 712, 276, 4, 911, 3247, 6664, 4333, 1264],
#   [1, 166, 712, 276, 4, 911, 3247, 6664, 4333, 1264, 35],
#   [1, 166, 712, 276, 4, 911, 3247, 6664, 4333, 1264, 35, 553],
#   [1, 166, 712, 276, 4, 911, 3247, 6664, 4333, 1264, 35, 553, 247],
#   [1, 166, 712, 276, 4, 911, 3247, 6664, 4333, 1264, 35, 553, 247, 1265],
#   [1, 166, 712, 276, 4, 911, 3247, 6664, 4333, 1264, 35, 553, 247, 1265, 160],
#   [1,
#    166,
#    712,
#    276,
#    4,
#    911,
#    3247,
#    6664,
#    4333,
#    1264,
#    35,
#    553,
#    247,
#    1265,
#    160,
#    1266],
#   [1534, 2222],
#   [1534, 2222, 22],
#   [1534, 2222, 22, 6665],
#   [1534, 2222, 22, 6665, 43],
#   [1534, 2222, 22, 6665, 43, 2616],
#   [1534, 2222, 22, 6665, 43, 2616, 7],
#   [1534, 2222, 22, 6665, 43, 2616, 7, 2608],
#   [1534, 2222, 22, 6665, 43, 2616, 7, 2608, 266],
#   [1534, 2222, 22, 6665, 43, 2616, 7, 2608, 266, 915],
#   [6666, 3248],
#   [6666, 3248, 248],
#   [6666, 3248, 248, 2617],
#   [6666, 3248, 248, 2617, 3248],
#   [6666, 3248, 248, 2617, 3248, 106],
#   [6666, 3248, 248, 2617, 3248, 106, 3249],
#   [6666, 3248, 248, 2617, 3248, 106, 3249, 247],
#   [6666, 3248, 248, 2617, 3248, 106, 3249, 247, 981],
#   [6666, 3248, 248, 2617, 3248, 106, 3249, 247, 981, 33],
#   [435, 532],
#   [435, 532, 63],
#   [435, 532, 63, 133],
#   [503, 1932],
#   [503, 1932, 1717],
#   [503, 1932, 1717, 176],
#   [503, 1932, 1717, 176, 6667],
#   [86, 757],
#   [86, 757, 6668],
#   [86, 757, 6668, 456],
#   [86, 757, 6668, 456, 197],
#   [86, 757, 6668, 456, 197, 1920],
#   [86, 757, 6668, 456, 197, 1920, 22],
#   [86, 757, 6668, 456, 197, 1920, 22, 6669],
#   [86, 757, 6668, 456, 197, 1920, 22, 6669, 6670],
#   [86, 757, 6668, 456, 197, 1920, 22, 6669, 6670, 6671],
#   [86, 757, 6668, 456, 197, 1920, 22, 6669, 6670, 6671, 6672],
#   [86, 757, 6668, 456, 197, 1920, 22, 6669, 6670, 6671, 6672, 1],
#   [86, 757, 6668, 456, 197, 1920, 22, 6669, 6670, 6671, 6672, 1, 140],
#   [86, 757, 6668, 456, 197, 1920, 22, 6669, 6670, 6671, 6672, 1, 140, 6673],
#   [86,
#    757,
#    6668,
#    456,
#    197,
#    1920,
#    22,
#    6669,
#    6670,
#    6671,
#    6672,
#    1,
#    140,
#    6673,
#    39],
#   [859, 13],
#   [859, 13, 105],
#   [859, 13, 105, 1163],
#   [859, 13, 105, 1163, 63],
#   [859, 13, 105, 1163, 63, 166],
#   [6674, 60],
#   [6674, 60, 6675],
#   [6674, 60, 6675, 21],
#   [6674, 60, 6675, 21, 66],
#   [6674, 60, 6675, 21, 66, 41],
#   [6674, 60, 6675, 21, 66, 41, 4334],
#   [6674, 60, 6675, 21, 66, 41, 4334, 6676],
#   [6674, 60, 6675, 21, 66, 41, 4334, 6676, 1542],
#   [392, 1],
#   [392, 1, 4335],
#   [392, 1, 4335, 21],
#   [392, 1, 4335, 21, 23],
#   [2618, 1],
#   [2618, 1, 1543],
#   [2618, 1, 1543, 16],
#   [2618, 1, 1543, 16, 21],
#   [2618, 1, 1543, 16, 21, 23],
#   [2618, 1, 1543, 16, 21, 23, 24],
#   [1, 6677],
#   [1, 6677, 6678],
#   [1, 6677, 6678, 7],
#   [1, 6677, 6678, 7, 6679],
#   [1, 6677, 6678, 7, 6679, 860],
#   [4336, 2614],
#   [4336, 2614, 12],
#   [4336, 2614, 12, 6680],
#   [4336, 2614, 12, 6680, 6681],
#   [4336, 2614, 12, 6680, 6681, 374],
#   [4336, 2614, 12, 6680, 6681, 374, 296],
#   [4336, 2614, 12, 6680, 6681, 374, 296, 8],
#   [4336, 2614, 12, 6680, 6681, 374, 296, 8, 6682],
#   [4336, 2614, 12, 6680, 6681, 374, 296, 8, 6682, 1725],
#   [245, 982],
#   [245, 982, 3250],
#   [245, 982, 3250, 758],
#   [245, 982, 3250, 758, 88],
#   [245, 982, 3250, 758, 88, 1726],
#   [245, 982, 3250, 758, 88, 1726, 231],
#   [245, 982, 3250, 758, 88, 1726, 231, 204],
#   [245, 982, 3250, 758, 88, 1726, 231, 204, 186],
#   [245, 982, 3250, 758, 88, 1726, 231, 204, 186, 6683],
#   [6684, 3251],
#   [6684, 3251, 608],
#   [6684, 3251, 608, 1727],
#   [6684, 3251, 608, 1727, 3252],
#   [6684, 3251, 608, 1727, 3252, 265],
#   [6685, 6686],
#   [6685, 6686, 2231],
#   [6685, 6686, 2231, 6],
#   [6685, 6686, 2231, 6, 4337],
#   [6685, 6686, 2231, 6, 4337, 249],
#   [6685, 6686, 2231, 6, 4337, 249, 668],
#   [6685, 6686, 2231, 6, 4337, 249, 668, 2619],
#   [6685, 6686, 2231, 6, 4337, 249, 668, 2619, 2231],
#   [2610, 803],
#   [2610, 803, 4],
#   [2610, 803, 4, 2620],
#   [5, 169],
#   [5, 169, 322],
#   [5, 169, 322, 21],
#   [5, 169, 322, 21, 23],
#   [5, 169, 322, 21, 23, 24],
#   [5, 169, 322, 21, 23, 24, 103],
#   [759, 129],
#   [759, 129, 640],
#   [759, 129, 640, 60],
#   [759, 129, 640, 60, 4295],
#   [637, 5],
#   [637, 5, 920],
#   [637, 5, 920, 223],
#   [637, 5, 920, 223, 910],
#   [637, 5, 920, 223, 910, 535],
#   [637, 5, 920, 223, 910, 535, 554],
#   [637, 5, 920, 223, 910, 535, 554, 194],
#   [6687, 4338],
#   [6687, 4338, 348],
#   [6687, 4338, 348, 258],
#   [6687, 4338, 348, 258, 134],
#   [6687, 4338, 348, 258, 134, 1933],
#   [6687, 4338, 348, 258, 134, 1933, 134],
#   [6687, 4338, 348, 258, 134, 1933, 134, 911],
#   [6687, 4338, 348, 258, 134, 1933, 134, 911, 1256],
#   [6687, 4338, 348, 258, 134, 1933, 134, 911, 1256, 321],
#   [6687, 4338, 348, 258, 134, 1933, 134, 911, 1256, 321, 757],
#   [6687, 4338, 348, 258, 134, 1933, 134, 911, 1256, 321, 757, 4339],
#   [6687, 4338, 348, 258, 134, 1933, 134, 911, 1256, 321, 757, 4339, 1264],
#   [6688, 244],
#   [6688, 244, 804],
#   [6688, 244, 804, 9],
#   [6688, 244, 804, 9, 6689],
#   [6690, 7],
#   [6690, 7, 2232],
#   [6690, 7, 2232, 19],
#   [6690, 7, 2232, 19, 13],
#   [6690, 7, 2232, 19, 13, 23],
#   [6690, 7, 2232, 19, 13, 23, 51],
#   [6691, 478],
#   [6691, 478, 126],
#   [247, 3253],
#   [247, 3253, 129],
#   [4340, 3254],
#   [4340, 3254, 6692],
#   [4340, 3254, 6692, 362],
#   [4340, 3254, 6692, 362, 129],
#   [80, 1934],
#   [80, 1934, 1164],
#   [80, 1934, 1164, 2621],
#   [80, 1934, 1164, 2621, 197],
#   [80, 1934, 1164, 2621, 197, 349],
#   [80, 1934, 1164, 2621, 197, 349, 2622],
#   [80, 1934, 1164, 2621, 197, 349, 2622, 323],
#   [80, 1934, 1164, 2621, 197, 349, 2622, 323, 307],
#   [80, 1934, 1164, 2621, 197, 349, 2622, 323, 307, 181],
#   [80, 1934, 1164, 2621, 197, 349, 2622, 323, 307, 181, 5],
#   [80, 1934, 1164, 2621, 197, 349, 2622, 323, 307, 181, 5, 2226],
#   [80, 1934, 1164, 2621, 197, 349, 2622, 323, 307, 181, 5, 2226, 4341],
#   [80, 1934, 1164, 2621, 197, 349, 2622, 323, 307, 181, 5, 2226, 4341, 380],
#   [80,
#    1934,
#    1164,
#    2621,
#    197,
#    349,
#    2622,
#    323,
#    307,
#    181,
#    5,
#    2226,
#    4341,
#    380,
#    1165],
#   [80,
#    1934,
#    1164,
#    2621,
#    197,
#    349,
#    2622,
#    323,
#    307,
#    181,
#    5,
#    2226,
#    4341,
#    380,
#    1165,
#    2233],
#   [2619, 2231],
#   [2619, 2231, 536],
#   [2619, 2231, 536, 48],
#   [2619, 2231, 536, 48, 6693],
#   [2619, 2231, 536, 48, 6693, 1935],
#   [24, 2603],
#   [24, 2603, 4296],
#   [24, 2603, 4296, 177],
#   [24, 2603, 4296, 177, 6],
#   [24, 2603, 4296, 177, 6, 861],
#   [24, 2603, 4296, 177, 6, 861, 39],
#   [24, 2603, 4296, 177, 6, 861, 39, 6694],
#   [363, 479],
#   [363, 479, 1067],
#   [363, 479, 1067, 2234],
#   [363, 479, 1067, 2234, 12],
#   [363, 479, 1067, 2234, 12, 6695],
#   [1068, 4342],
#   [1408, 1544],
#   [1408, 1544, 6],
#   [1408, 1544, 6, 6696],
#   [1408, 1544, 6, 6696, 3255],
#   [1408, 1544, 6, 6696, 3255, 4343],
#   [1408, 1544, 6, 6696, 3255, 4343, 126],
#   [298, 22],
#   [298, 22, 1545],
#   [298, 22, 1545, 3256],
#   [298, 22, 1545, 3256, 2235],
#   [298, 22, 1545, 3256, 2235, 417],
#   [298, 22, 1545, 3256, 2235, 417, 6697],
#   [298, 22, 1545, 3256, 2235, 417, 6697, 173],
#   [298, 22, 1545, 3256, 2235, 417, 6697, 173, 6698],
#   [298, 22, 1545, 3256, 2235, 417, 6697, 173, 6698, 156],
#   [298, 22, 1545, 3256, 2235, 417, 6697, 173, 6698, 156, 232],
#   [308, 555],
#   [308, 555, 124],
#   [308, 555, 124, 39],
#   [308, 555, 124, 39, 4344],
#   [308, 555, 124, 39, 4344, 4345],
#   [308, 555, 124, 39, 4344, 4345, 553],
#   [308, 555, 124, 39, 4344, 4345, 553, 575],
#   [1069, 2623],
#   [1069, 2623, 2624],
#   [1069, 2623, 2624, 238],
#   [1069, 2623, 2624, 238, 7],
#   [1069, 2623, 2624, 238, 7, 440],
#   [1069, 2623, 2624, 238, 7, 440, 2236],
#   [1069, 2623, 2624, 238, 7, 440, 2236, 191],
#   [6699, 1409],
#   [6699, 1409, 1398],
#   [6699, 1409, 1398, 4346],
#   [6699, 1409, 1398, 4346, 983],
#   [6699, 1409, 1398, 4346, 983, 72],
#   [6699, 1409, 1398, 4346, 983, 72, 1],
#   [6699, 1409, 1398, 4346, 983, 72, 1, 3257],
#   [6699, 1409, 1398, 4346, 983, 72, 1, 3257, 3258],
#   [435, 532],
#   [435, 532, 480],
#   [435, 532, 480, 133],
#   [435, 532, 480, 133, 12],
#   [435, 532, 480, 133, 12, 4347],
#   [6700, 66],
#   [6700, 66, 12],
#   [6700, 66, 12, 641],
#   [6700, 66, 12, 641, 2237],
#   [6700, 66, 12, 641, 2237, 127],
#   [6700, 66, 12, 641, 2237, 127, 6701],
#   [6700, 66, 12, 641, 2237, 127, 6701, 5],
#   [6700, 66, 12, 641, 2237, 127, 6701, 5, 259],
#   [1166, 5],
#   [1166, 5, 4348],
#   [1166, 5, 4348, 6],
#   [1166, 5, 4348, 6, 5],
#   [1166, 5, 4348, 6, 5, 605],
#   [1166, 5, 4348, 6, 5, 605, 2625],
#   [713, 1],
#   [713, 1, 862],
#   [713, 1, 862, 611],
#   [713, 1, 862, 611, 349],
#   [713, 1, 862, 611, 349, 6702],
#   [713, 1, 862, 611, 349, 6702, 1410],
#   [713, 1, 862, 611, 349, 6702, 1410, 287],
#   [669, 45],
#   [669, 45, 1],
#   [669, 45, 1, 16],
#   [669, 45, 1, 16, 120],
#   [669, 45, 1, 16, 120, 66],
#   [669, 45, 1, 16, 120, 66, 277],
#   [977, 226],
#   [977, 226, 6703],
#   [977, 226, 6703, 126],
#   [6704, 5],
#   [6704, 5, 231],
#   [6704, 5, 231, 9],
#   [6704, 5, 231, 9, 1],
#   [6704, 5, 231, 9, 1, 132],
#   [6704, 5, 231, 9, 1, 132, 118],
#   [6704, 5, 231, 9, 1, 132, 118, 8],
#   [6704, 5, 231, 9, 1, 132, 118, 8, 476],
#   [6704, 5, 231, 9, 1, 132, 118, 8, 476, 1267],
#   [6704, 5, 231, 9, 1, 132, 118, 8, 476, 1267, 132],
#   [6704, 5, 231, 9, 1, 132, 118, 8, 476, 1267, 132, 537],
#   [1411, 1546],
#   [1411, 1546, 7],
#   [1411, 1546, 7, 1547],
#   [1411, 1546, 7, 1547, 19],
#   [1411, 1546, 7, 1547, 19, 42],
#   [1411, 1546, 7, 1547, 19, 42, 23],
#   [1411, 1546, 7, 1547, 19, 42, 23, 24],
#   [16, 120],
#   [16, 120, 66],
#   [16, 120, 66, 277],
#   [16, 120, 66, 277, 20],
#   [16, 120, 66, 277, 20, 1],
#   [16, 120, 66, 277, 20, 1, 6705],
#   [16, 120, 66, 277, 20, 1, 6705, 6706],
#   [435, 532],
#   [435, 532, 5],
#   [435, 532, 5, 224],
#   [435, 532, 5, 224, 267],
#   [435, 532, 5, 224, 267, 1728],
#   [435, 532, 5, 224, 267, 1728, 224],
#   [435, 532, 5, 224, 267, 1728, 224, 267],
#   [435, 532, 5, 224, 267, 1728, 224, 267, 1729],
#   [1070, 80],
#   [1070, 80, 260],
#   [1070, 80, 260, 2626],
#   [1070, 80, 260, 2626, 3259],
#   [1070, 80, 260, 2626, 3259, 33],
#   [1070, 80, 260, 2626, 3259, 33, 437],
#   [1070, 80, 260, 2626, 3259, 33, 437, 984],
#   [1070, 80, 260, 2626, 3259, 33, 437, 984, 981],
#   [248, 4349],
#   [248, 4349, 4350],
#   [248, 4349, 4350, 2627],
#   [3260, 3260],
#   [3260, 3260, 134],
#   [3260, 3260, 134, 6707],
#   [3260, 3260, 134, 6707, 760],
#   [3260, 3260, 134, 6707, 760, 4351],
#   [1064, 153],
#   [1064, 153, 187],
#   [1064, 153, 187, 1167],
#   [1064, 153, 187, 1167, 1],
#   [1064, 153, 187, 1167, 1, 761],
#   [1064, 153, 187, 1167, 1, 761, 141],
#   [1064, 153, 187, 1167, 1, 761, 141, 714],
#   [1064, 153, 187, 1167, 1, 761, 141, 714, 272],
#   [1064, 153, 187, 1167, 1, 761, 141, 714, 272, 576],
#   [394, 11],
#   [394, 11, 250],
#   [394, 11, 250, 4352],
#   [394, 11, 250, 4352, 4353],
#   [394, 11, 250, 4352, 4353, 45],
#   [394, 11, 250, 4352, 4353, 45, 395],
#   [1730, 3261],
#   [1730, 3261, 456],
#   [1730, 3261, 456, 4],
#   [1730, 3261, 456, 4, 337],
#   [1730, 3261, 456, 4, 337, 269],
#   [1730, 3261, 456, 4, 337, 269, 8],
#   [1730, 3261, 456, 4, 337, 269, 8, 48],
#   [1730, 3261, 456, 4, 337, 269, 8, 48, 3262],
#   [1, 98],
#   [1, 98, 16],
#   [1, 98, 16, 1548],
#   [1, 98, 16, 1548, 805],
#   [1, 98, 16, 1548, 805, 36],
#   [1, 98, 16, 1548, 805, 36, 134],
#   [1, 98, 16, 1548, 805, 36, 134, 1],
#   [1, 98, 16, 1548, 805, 36, 134, 1, 98],
#   [1, 98, 16, 1548, 805, 36, 134, 1, 98, 3263],
#   [1, 98, 16, 1548, 805, 36, 134, 1, 98, 3263, 4354],
#   [1, 98, 16, 1548, 805, 36, 134, 1, 98, 3263, 4354, 134],
#   [1, 98, 16, 1548, 805, 36, 134, 1, 98, 3263, 4354, 134, 6708],
#   [1, 98, 16, 1548, 805, 36, 134, 1, 98, 3263, 4354, 134, 6708, 64],
#   [1, 98, 16, 1548, 805, 36, 134, 1, 98, 3263, 4354, 134, 6708, 64, 244],
#   [1541, 2230],
#   [1541, 2230, 2628],
#   [1541, 2230, 2628, 5],
#   [1541, 2230, 2628, 5, 4355],
#   [1541, 2230, 2628, 5, 4355, 1168],
#   [1541, 2230, 2628, 5, 4355, 1168, 6709],
#   [1541, 2230, 2628, 5, 4355, 1168, 6709, 762],
#   [1541, 2230, 2628, 5, 4355, 1168, 6709, 762, 863],
#   [1541, 2230, 2628, 5, 4355, 1168, 6709, 762, 863, 985],
#   [1541, 2230, 2628, 5, 4355, 1168, 6709, 762, 863, 985, 8],
#   [1541, 2230, 2628, 5, 4355, 1168, 6709, 762, 863, 985, 8, 1],
#   [1541, 2230, 2628, 5, 4355, 1168, 6709, 762, 863, 985, 8, 1, 921],
#   [1541, 2230, 2628, 5, 4355, 1168, 6709, 762, 863, 985, 8, 1, 921, 224],
#   [1541, 2230, 2628, 5, 4355, 1168, 6709, 762, 863, 985, 8, 1, 921, 224, 477],
#   [1541,
#    2230,
#    2628,
#    5,
#    4355,
#    1168,
#    6709,
#    762,
#    863,
#    985,
#    8,
#    1,
#    921,
#    224,
#    477,
#    455],
#   [1258, 6710],
#   [1258, 6710, 404],
#   [1258, 6710, 404, 986],
#   ...],
#  16449)

# %%
from tensorflow.keras.utils import to_categorical

def generate_padded_sequences(input_sequences):
    max_sequence_len = max([len(x) for x in input_sequences]) #Length of largest sequence  #27
    input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre')) #Padding sequences (from the start) to make them of same length


    predictors, label = input_sequences[:,:-1],input_sequences[:,-1] #Separating predictors and target label
    label = to_categorical(label, num_classes=total_words)
    return predictors, label, max_sequence_len

# %%
predictors, label, max_sequence_len = generate_padded_sequences(inp_sequences)

# %%
def create_model(max_sequence_len, total_words):
    input_len = max_sequence_len - 1
    model = Sequential()
    
    # Add Input Embedding Layer
    model.add(Embedding(total_words, 10, input_length=input_len))
    
    # Add Hidden Layer 1 - LSTM Layer
    model.add(LSTM(100))
    model.add(Dropout(0.1))
    
    # Add Output Layer
    model.add(Dense(total_words, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam')
    
    return model

model = create_model(max_sequence_len, total_words)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 26, 10)            164490
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               44400
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense (Dense)                (None, 16449)             1661349
# =================================================================
# Total params: 1,870,239
# Trainable params: 1,870,239
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(predictors, label, epochs=20, verbose=1)
# Out:
# Epoch 1/20
# 2353/2353 [==============================] - 19s 8ms/step - loss: 6.6108
# Epoch 2/20
# 2353/2353 [==============================] - 19s 8ms/step - loss: 6.2321
# Epoch 3/20
# 2353/2353 [==============================] - 19s 8ms/step - loss: 5.8267
# Epoch 4/20
# 2353/2353 [==============================] - 19s 8ms/step - loss: 5.4490
# Epoch 5/20
# 2353/2353 [==============================] - 19s 8ms/step - loss: 5.1105
# Epoch 6/20
# 2353/2353 [==============================] - 19s 8ms/step - loss: 4.8056
# Epoch 7/20
# 2353/2353 [==============================] - 19s 8ms/step - loss: 4.5351
# Epoch 8/20
# 2353/2353 [==============================] - 19s 8ms/step - loss: 4.2900
# Epoch 9/20
# 2353/2353 [==============================] - 19s 8ms/step - loss: 4.0643
# Epoch 10/20
# 2353/2353 [==============================] - 20s 8ms/step - loss: 3.8537
# Epoch 11/20
# 2353/2353 [==============================] - 19s 8ms/step - loss: 3.6581
# Epoch 12/20
# 2353/2353 [==============================] - 19s 8ms/step - loss: 3.4799
# Epoch 13/20
# 2353/2353 [==============================] - 19s 8ms/step - loss: 3.3171
# Epoch 14/20
# 2353/2353 [==============================] - 19s 8ms/step - loss: 3.1617
# Epoch 15/20
# 2353/2353 [==============================] - 19s 8ms/step - loss: 3.0260
# Epoch 16/20
# 2353/2353 [==============================] - 19s 8ms/step - loss: 2.8922
# Epoch 17/20
# 2353/2353 [==============================] - 19s 8ms/step - loss: 2.7739
# Epoch 18/20
# 2353/2353 [==============================] - 19s 8ms/step - loss: 2.6619
# Epoch 19/20
# 2353/2353 [==============================] - 19s 8ms/step - loss: 2.5652
# Epoch 20/20
# 2353/2353 [==============================] - 19s 8ms/step - loss: 2.4713

# %%
def generate_text(seed_text, next_words, model, max_sequence_len):
    for i in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]  #(E.g. [12,34,45,565,20]) #Sequence of tokens (Same as before)
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre') #Padding
        predicted = model.predict_classes(token_list, verbose=2)


        output_word = ""
        for word,index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " "+output_word
    return seed_text.title()

# %%
print(generate_text("Pakistan", 5, model, max_sequence_len))
# Out:
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# 1/1 - 0s
# Pakistan Drama Mere Bewafa Episode 13
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
